# %% [markdown]
# # Business Analytics - Lumina Technology
#
# Members:
# * Sakshi Dilip Channawar, responseible for finding insights and performing t-test
# * Darin Engkawong, responsible for finding insights and performing t-test
# * Thi Hieu Ngan Tran (Rosa), responsible for finding insights, writing report, running predictive models, developing recommendations.
# * Mai Trong Nghia Hoang (Edward), responsible for data exploration/preparation, finding insights, writing report, suggesting recommendations, building predictive models.

# %% [markdown]
# ## **1. DATA EXPLORATION AND PREPARATION**

# %% [markdown]
# ### **A. Data Overview**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

import warnings
warnings.filterwarnings("ignore")

# %%
# Use 'ISO-8859-1' or 'latin1' encoding
data_2012 = pd.read_csv('2012_Data.csv', encoding='ISO-8859-1')
data_2013 = pd.read_csv('2013_Data.csv', encoding='ISO-8859-1')

# %%
# Merge the data
data = pd.concat([data_2012, data_2013], ignore_index=True)

# %%
# Display a few rows of the dataset

data.head(2)
# Out:
#    accounting_date  fiscal_year  fiscal_month  calendar_year  calendar_month  \
# 0         20120509         2012            11           2012               5
# 1         20120216         2012             8           2012               2
#
#    calendar_day  company_code customer_code  customer_district_code  \
# 0             9           101     411800601                     410
# 1            16           101     361000403                     300
#
#                         item_code  ... value_quantity value_price_adjustment  \
# 0  GENIE8WWWBC                     ...           84.0                      0
# 1  GENIE8WWWBC                     ...           12.0                      0
#
#   currency  item_source_class invoice_number line_number invoice_date  \
# 0      AUD                NaN        2217887           1     20120509
# 1      AUD                NaN        2185745           1     20120216
#
#   customer_order_number order_date dss_update_time
# 0               2865354   20120509         49:58.7
# 1               2833515   20120216         49:58.7
#
# [2 rows x 41 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1988382 entries, 0 to 1988381
# Data columns (total 41 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   accounting_date           int64
#  1   fiscal_year               int64
#  2   fiscal_month              int64
#  3   calendar_year             int64
#  4   calendar_month            int64
#  5   calendar_day              int64
#  6   company_code              int64
#  7   customer_code             object
#  8   customer_district_code    int64
#  9   item_code                 object
#  10  business_area_code        object
#  11  item_group_code           object
#  12  item_class_code           object
#  13  item_type                 int64
#  14  bonus_group_code          object
#  15  environment_group_code    object
#  16  technology_group_code     object
#  17  commission_group_code     object
#  18  reporting_classification  object
#  19  light_source              object
#  20  warehouse_code            object
#  21  abc_class_code            object
#  22  abc_class_volume          object
#  23  business_chain_l1_code    object
#  24  business_chain_l1_name    object
#  25  contact_method_code       object
#  26  salesperson_code          object
#  27  order_type_code           object
#  28  market_segment            object
#  29  value_sales               float64
#  30  value_cost                float64
#  31  value_quantity            float64
#  32  value_price_adjustment    int64
#  33  currency                  object
#  34  item_source_class         float64
#  35  invoice_number            int64
#  36  line_number               int64
#  37  invoice_date              int64
#  38  customer_order_number     object
#  39  order_date                int64
#  40  dss_update_time           object
# dtypes: float64(4), int64(14), object(23)
# memory usage: 622.0+ MB

# %%
# Check unique values and their formats in each feature

for col in data.columns:
    uniques = data[col].unique()
    print(col)
    print(uniques)
    print("-" * 50)
# Out:
# accounting_date
# [20120509 20120216 20120518 20120109 20120504 20120626 20120605 20120622
#  20120403 20120418 20120118 20120117 20120420 20120404 20120423 20120125
#  20130121 20130408 20130103 20130417 20130213 20130418 20130508 20130322
#  20130205 20130219 20130529 20130123 20130412 20130318 20130215 20130313
#  20130323 20130204 20130114 20130518 20130301 20130320 20130104 20130102
#  20130610 20130622 20130128 20130519 20130106 20130329 20131120 20130902
#  20130905 20131119 20131121 20130805 20130809 20131113 20131114 20131206
#  20131213 20131031 20130723 20130704 20130806 20130909 20131211 20131128
#  20131107 20131204 20131024 20130719 20131028 20130701 20130716 20130715
#  20131219 20130912 20130731 20131111 20130910 20131202 20131010 20130920
#  20131007 20131122 20130710 20131015 20131008 20131001 20131210 20131217
#  20131014 20131105 20131011 20131029 20130827 20130823 20130930 20131125
#  20131018 20131004 20131025 20131030 20131017 20130712 20130904 20131023
#  20130709 20130927 20130718 20130802 20130816 20130812 20130911 20130821
#  20130819 20131009 20130906 20130708 20130814 20131118 20130913 20131115
#  20131129 20131016 20131126 20130702 20130918 20130703 20130903 20131101
#  20130725 20130705 20130926 20130829 20130729 20131212 20131203 20130808
#  20130917 20130815 20131003 20130830 20131218 20130717 20130711 20131108
#  20130730 20130925 20130919 20130801 20130924 20130820 20131021 20131112
#  20131216 20130722 20131104 20130828 20131205 20131022 20130726 20131002
#  20130826 20131106 20130807 20131220 20130724 20131214 20130916 20130813
#  20131127 20130822 20131207 20130923 20131209 20131231 20131224 20131227
#  20131223 20131230 20131222 20131123 20131116 20130727 20130831]
# --------------------------------------------------
# fiscal_year
# [2012 2013 2014]
# --------------------------------------------------
# fiscal_month
# [11  8  7 12 10  9  3  5  6  1  2  4]
# --------------------------------------------------
# calendar_year
# [2012 2013]
# --------------------------------------------------
# calendar_month
# [ 5  2  1  6  4  3  9 11 12  7  8 10]
# --------------------------------------------------
# calendar_day
# [ 9 16 18  4 26  5 22  3 17 20 23 25 27 19  6 10 21 11  8 30 15 14  2 28
#   1  7 31 24 13 12 29]
# --------------------------------------------------
# company_code
# [101 100 140 205 170 220 950 240 510 120]
# --------------------------------------------------
# customer_code
# [411800601 361000403 565540415 ... 'ZI2000017 ' 'Z85020601 ' '434790100']
# --------------------------------------------------
# customer_district_code
# [410 300 500 310 400 200 210 720 710 600 510 530 535 540 520 545 100]
# --------------------------------------------------
# item_code
# ['GENIE8WWWBC                   ' 'GENIE11WWWES                  '
#  'GENIE18WCDLES                 ' ... 'DT3132221822ADW               '
#  'DT34675139E                   ' '0.90811.00-910                ']
# --------------------------------------------------
# business_area_code
# ['LMP                           ' 'FLD                           '
#  'OTH                           ' 'SUR                           '
#  'COM                           ' 'DLT                           '
#  'TRO                           ' 'URB                           '
#  'HLB                           ' 'SAE                           '
#  'RWY                           ' 'LCP                           '
#  'PEN                           ' 'EXL                           '
#  'TAL                           ' '945' '950' '980' '920' '960' '910'
#  '930' '999' '970' '940' '985' 'IAE                           '
#  'IAI                           ']
# --------------------------------------------------
# item_group_code
# ['LMP01008                      ' 'FLD03002                      ' '999'
#  'SUR08001                      ' 'FLD02002                      '
#  'COM90001                      ' 'DLT01002                      '
#  'TRO03001                      ' 'COM99001                      '
#  'SUR80001                      ' 'URB04002                      '
#  'FLD90001                      ' 'SUR09001                      '
#  'COM08001                      ' 'HLB02002                      '
#  'URB04001                      ' 'SAE02001                      '
#  'TRO02001                      ' 'SUR01001                      '
#  'RWY01001                      ' 'COM07001                      '
#  'COM12001                      ' 'LCP02001                      '
#  'LMP04002                      ' 'SAE90001                      '
#  'SUR04001                      ' 'TRO90001                      '
#  'TRO02002                      ' 'TRO02004                      '
#  'SAE80001                      ' 'FLD01002                      '
#  'SAE01001                      ' 'SAE02002                      '
#  'SUR99001                      ' 'SUR90001                      '
#  'TRO80001                      ' 'TRO03004                      '
#  'SAE01002                      ' 'HLB02001                      '
#  'DLT04002                      ' 'DLT02002                      '
#  'PEN01003                      ' 'COM10001                      '
#  'URB03001                      ' 'LMP01001                      '
#  'EXL01001                      ' 'DLT90001                      '
#  'COM06001                      ' 'COM16001                      '
#  'URB02001                      ' 'URB90001                      '
#  'SUR05001                      ' 'TRO99001                      '
#  'TRO01001                      ' 'COM19001                      '
#  'TRO03002                      ' 'SUR07002                      '
#  'RWY90001                      ' 'FLD02004                      '
#  'HLB01001                      ' 'RWY02001                      '
#  'FLD99001                      ' 'SUR07001                      '
#  'COM01001                      ' 'TAL05001                      '
#  'HLB01003                      ' 'LMP06001                      '
#  'SUR03001                      ' 'TRO03003                      '
#  'HLB90001                      ' 'TRO02003                      '
#  'EXL06001                      ' 'SUR07003                      '
#  'EXL90001                      ' 'COM14001                      '
#  'SUR06002                      ' 'COM09001                      '
#  'TAL90001                      ' 'COM05001                      '
#  'LMP03002                      ' 'COM03002                      '
#  'COM17001                      ' 'SUR06001                      '
#  'RWY99001                      ' 'LCP01004                      '
#  'COM03003                      ' 'COM03001                      '
#  'COM15001                      ' 'FLD01004                      '
#  'LMP06002                      ' 'LMP03013                      '
#  'RWY03001                      ' 'DLT01001                      '
#  'TRO01003                      ' 'RWY01003                      '
#  'TRO02005                      ' 'DLT99001                      '
#  'LMP99001                      ' 'COM13001                      '
#  'EXL99001                      ' 'LMP03001                      '
#  'COM04001                      ' 'LCP01001                      '
#  'COM18001                      ' 'HLB99001                      '
#  'TAL04001                      ' 'SAE99001                      '
#  'COM80001                      ' 'LMP03012                      '
#  'LMP06004                      ' 'LMP04014                      '
#  'LMP09001                      ' 'LMP01007                      '
#  'PEN01001                      ' 'URB99001                      '
#  'COM02001                      ' 'LMP01005                      ' '270'
#  'SUR02001                      ' 'RWY06001                      ' '660'
#  '50' 'LMP06010                      ' 'LMP10014                      '
#  'LMP01002                      ' 'COM11001                      '
#  'LMP11001                      ' '271' '038B                          '
#  '427' 'LMP04013                      ' '1'
#  'LMP07001                      ' '97' '248' '2' '64' '40' '533' '30'
#  '720' '532' '336' '722' 'LMP04004                      ' '74' '530' '721'
#  'URB01002                      ' 'URB05001                      '
#  'A42                           ' '66' '350' '220' '94'
#  'LMP01006                      ' '315' 'LMP06005                      '
#  'LMP10008                      ' 'LMP10002                      ' '10008'
#  'LMP06003                      ' 'A45                           '
#  'LMP02001                      ' '038A                          '
#  'LMP05015                      ' '340' '342' '130'
#  'COM70001                      ' '82' '711'
#  'DLT05002                      ' 'LMP01004                      '
#  'PEN90001                      ' 'LMP10006                      ' '28'
#  '73' '10' '970' 'P12015                        '
#  'LMP07002                      ' '531' '10007' '198'
#  'B34                           ' 'P12051                        ' '208'
#  '230' 'LMP03009                      ' '11047' '317'
#  'LMP03011                      ' '300' 'B27                           '
#  'B31                           ' '190' 'LMP04012                      '
#  '704' 'FLD04002                      ' '908'
#  'LMP04016                      ' 'A48                           ' '224'
#  '308' 'DLT02003                      ' 'DLT01003                      '
#  'EXL01002                      ' '161' 'LMP05023                      '
#  'LMP03006                      ' '95' 'LMP05003                      '
#  'LMP05002                      ' '374' 'EXL02001                      '
#  '195' '399' '53' 'DLT03002                      '
#  'TAL07001                      ' 'TAL99001                      '
#  'LMP05017                      ' '419' 'EXL02002                      '
#  '24' 'EXL05001                      ' 'LMP03007                      '
#  'LMP03008                      ' 'LMP03005                      '
#  'LMP05020                      ' 'LMP05013                      ' '16338'
#  'LMP05024                      ' 'LMP05028                      '
#  'LMP05026                      ' '17000' 'LMP04008                      '
#  '16310' '17080' '17030' 'SUR10001                      '
#  'LMP05007                      ' 'LMP05008                      '
#  'LMP05010                      ' '17090' 'LMP05009                      '
#  '250170' '250155' '16332' '16340' '16320'
#  'LMP05019                      ' '16318' 'LMP04006                      '
#  'LMP05025                      ' 'LMP05012                      ' '16102'
#  'LMP05014                      ' 'LMP04017                      ' '16324'
#  'LMP05018                      ' 'LMP03015                      '
#  'TAL01001                      ' 'TAL02001                      ' '16606'
#  'FLD02003                      ' 'TAL08001                      ' '16612'
#  'LMP05016                      ' 'LMP05001                      '
#  'LMP05005                      ' 'LMP05004                      '
#  '251230' 'LMP05027                      ' '251235'
#  'LMP05022                      ' 'LMP05006                      '
#  '251625' 'LMP04011                      '
#  'FLD04001                      ' 'LMP04001                      ' '16602'
#  'LMP04019                      ' '250505'
#  'SUR12001                      ' 'SUR11001                      '
#  '251545' 'SUR13001                      ' '251410' '251405' '250510'
#  'SUR14001                      ' '250805'
#  'IAE05001                      ' 'TAL01003                      '
#  '251635' '250715' 'PEN04001                      ' '251105'
#  'PEN08001                      ' '250915' '250410'
#  'DLT02001                      ' '250920' '251005' '251720'
#  'LMP04009                      ' '250905' '250405' '250815' '251210'
#  'LMP03003                      ' 'DLT03003                      '
#  '251015' '250165' '250150' '17500' '16118'
#  'LMP03004                      ' '251220' '250110'
#  'DLT04003                      ' '250425'
#  'URB05002                      ' '16128' 'LMP04003                      '
#  '250830' 'LMP01003                      ' '250810'
#  'LMP01010                      ' '251540' '250420' '250130' '251215'
#  '251615' '16702' 'LMP04005                      ' '250910' '250160'
#  'LMP04010                      ' 'LMP01009                      '
#  '250105' '251310' 'PEN01004                      '
#  'PEN01002                      ' 'LMP10005                      '
#  'LMP10004                      ' 'LMP10016                      '
#  'LCP90001                      ' '17010' '250125' '250135'
#  'LCP01002                      ' '17020' 'RWY01002                      '
#  'LF100000                      ' 'RWY02002                      ' '17050'
#  'TAL02002                      ' 'FASTRA00                      '
#  'NUALIG00                      ' 'FGALAX00                      '
#  'TAL06001                      ' '17070' 'LP900000                      '
#  'FFLUSH00                      ' 'SA2MAX00                      '
#  'NSTCKPLE                      ' 'TAL01008                      '
#  'CSECON00                      ' 'GHIDIN00                      '
#  'PEN09001                      ' 'FBULLS00                      '
#  'FLD03004                      ' 'CSELIG00                      '
#  'TAL06004                      ' 'FSYLEC00                      '
#  'RPIXEL00                      ' 'LCP99001                      '
#  'TAL02004                      ' 'PEN10001                      '
#  'TAL06005                      ' 'NSTCKFIX                      '
#  'LMP90001                      ' 'LMP04018                      '
#  'NSTCKCCD                      ' 'OTHER71                       '
#  'CEQUIL00                      ' 'FSLIML00                      '
#  'FLD02001                      ' 'CSLIMD00                      '
#  'LPUNTO00                      ' 'CSIGNO00                      '
#  'LL100000                      ' 'LL300000                      '
#  'CSEEXWN0                      ' 'PEN90002                      '
#  'LMP10007                      ' 'LMP06009                      '
#  'CLED150T                      ' 'TAL02003                      '
#  'CSEFFL00                      ' 'LMP10011                      '
#  'CSEGLA00                      ' 'RROADS00                      '
#  'LC500000                      ' 'SS1MIN00                      '
#  'LMP05029                      ' 'LMP10020                      '
#  'LMP10021                      ' 'CMOTIF00                      '
#  'TAL04005                      ' 'CINSTA00                      '
#  'LMP10023                      ' 'RWY04001                      '
#  'TAL01004                      ' 'LB500000                      '
#  'TAL04003                      ' 'COV65000                      '
#  'SMODAR00                      ' 'OTHER91                       '
#  'CLED100T                      ' 'TAL01009                      '
#  'CLYTE300                      ' 'LMP06007                      '
#  'CEQUI400                      ' 'TAL01007                      '
#  'CTORUS00                      ' 'CSTDEV00                      '
#  'CTEQSP00                      ' 'LC230000                      '
#  'LA300000                      ' 'TAL01002                      '
#  'LMP07004                      ' 'COFFLY00                      '
#  'RTUNPS00                      ' 'CSTPRO00                      '
#  'FPIRAN00                      ' 'LMP05030                      '
#  'LA100000                      ' 'CMYRIA00                      '
#  'LA900000                      ' 'LMP04015                      '
#  'LG370000                      ' 'LMP10024                      '
#  'FRAWMA00                      ' 'LD250000                      '
#  'IAI10001                      ' 'LMP10003                      '
#  'LL400000                      ' 'LMP12001                      '
#  'LG150000                      ' 'LS010000                      '
#  'CSTERL00                      ' 'CSKYLI00                      '
#  'CMONIT00                      ' 'CINSA175                      '
#  'LD320000                      ' 'CGIOTT00                      '
#  'TAL02005                      ' 'CINPACT0                      '
#  'CINSE120                      ' 'CAXOXL00                      '
#  'CGIRO000                      ' 'LG420000                      '
#  'CCASSI00                      ' 'FSYCAP00                      '
#  'CPIXO000                      ' 'TAL01010                      '
#  'COPALI00                      ' 'LD490000                      '
#  'SQUADT00                      ' 'CINSA225                      '
#  'SNOVAL00                      ' 'CGI33500                      '
#  'LK010000                      ' 'CINSAR00                      '
#  'CINST900                      ' 'CINST700                      '
#  'CBEACO00                      ' 'CSIGN155                      '
#  'LC210000                      ' 'LC410000                      '
#  'LC100000                      ' 'LG900000                      '
#  'FPOLES00                      ' 'LMP10013                      '
#  'LG380000                      ' 'CDECAP00                      ' '240'
#  'N85                           ' '416' 'N59                           '
#  'N75                           ' '418' '243' '723'
#  'N51                           ' '431' 'FLRSTK                        '
#  '239' '510' '17040' 'TAL01005                      '
#  'LMP10018                      ' 'PEN03001                      ' '180'
#  'FLD01003                      ' '355' '16626' '209' '44' '421' '725'
#  '359' 'FLD01001                      ' 'DLT04004                      '
#  '120' '995' 'CMOT8200                      '
#  'CINSTAR8                      ' 'CINSE100                      '
#  'CBRIO000                      ' 'DLT03001                      '
#  'FCUBAN00                      ' 'CFOLIO00                      '
#  'FTRITO00                      ' 'CEQIN300                      '
#  'LA350000                      ' 'CLYTES00                      '
#  'LL500000                      ' 'SCITYL00                      '
#  'CCIELO00                      ' 'SR1MIN00                      '
#  'TAL07002                      ' 'OTHER75                       '
#  'CINSA150                      ' 'FILIA000                      ' '193'
#  'IAI09001                      ' '251305' '16312'
#  'PEN04003                      ' '20' 'CSEEB000                      '
#  '250520' 'HLB01002                      '
#  'LC010000                      ' '251525'
#  'FLINEA00                      ' 'CSEEXDN0                      '
#  'LMP09002                      ' 'CSIGN115                      '
#  'OTHER92                       ' '231' 'LMP08001                      '
#  'CACCES00                      ' 'LG100000                      '
#  'SA1MIN00                      ' 'LMP10017                      '
#  'LMP10022                      ' 'P12197                        ' '11021'
#  'LCP01003                      ' '6000' 'RWY03002                      '
#  'HLB80001                      ' 'EXL03001                      '
#  'CSEFC000                      ' 'CEXFNII0                      '
#  'NSTCKOTH                      ' 'RWY05001                      '
#  'RSOLAR00                      ' 'LL600000                      '
#  'RRAWMA00                      ' 'SA2MIN00                      '
#  'CINST800                      ' 'CSEARMA0                      '
#  'CPENTO00                      ' 'LCP02002                      '
#  'TAL04002                      ' 'SSM30000                      '
#  'DLT01004                      ' 'FSUPER00                      '
#  'OTHER76                       ' 'CROTOS00                      '
#  'FBLINE00                      ' '250140' '670'
#  'IAI05001                      ' 'P12044                        '
#  'TAL02006                      ' 'SEL                           '
#  'CSECSDE0                      ' 'FGTRAY00                      '
#  'CSETBE40                      ' 'CFJB3A00                      '
#  'CFJB2A00                      ' 'NSTCKLMP                      ' '16124'
#  'CFJB0A00                      ' 'PEN99001                      '
#  'IAI08001                      ' 'LMP10009                      '
#  'CDLREC00                      ' 'PEN03003                      '
#  'FCOURT00                      ' 'FLD03001                      ' '980'
#  'SCLSPO00                      ' 'FBENEL00                      '
#  'FRAVEN0L                      ' 'IAI11001                      ']
# --------------------------------------------------
# item_class_code
# ['LMP01                         ' 'FLD03                         ' '14001'
#  'SUR08                         ' 'FLD02                         '
#  'COM90                         ' 'DLT01                         '
#  'TRO03                         ' 'COM99                         '
#  'SUR80                         ' 'URB04                         '
#  'FLD90                         ' 'SUR09                         '
#  'COM08                         ' 'HLB02                         '
#  'SAE02                         ' 'TRO02                         '
#  'SUR01                         ' 'RWY01                         '
#  'COM07                         ' 'COM12                         '
#  'LCP02                         ' 'LMP04                         '
#  'SAE90                         ' 'SUR04                         '
#  'TRO90                         ' 'SAE80                         '
#  'FLD01                         ' 'SAE01                         '
#  'SUR99                         ' 'SUR90                         '
#  'TRO80                         ' 'DLT04                         '
#  'DLT02                         ' 'PEN01                         '
#  'COM10                         ' 'URB03                         '
#  'EXL01                         ' 'DLT90                         '
#  'COM06                         ' 'COM16                         '
#  'URB02                         ' 'URB90                         '
#  'SUR05                         ' 'TRO99                         '
#  'TRO01                         ' 'COM19                         '
#  'SUR07                         ' 'RWY90                         '
#  'HLB01                         ' 'RWY02                         '
#  'FLD99                         ' 'COM01                         '
#  'TAL05                         ' 'LMP06                         '
#  'SUR03                         ' 'HLB90                         '
#  'EXL06                         ' 'EXL90                         '
#  'COM14                         ' 'SUR06                         '
#  'COM09                         ' 'TAL90                         '
#  'COM05                         ' 'LMP03                         '
#  'COM03                         ' 'COM17                         '
#  'RWY99                         ' 'LCP01                         '
#  'COM15                         ' 'RWY03                         '
#  'DLT99                         ' 'LMP99                         '
#  'COM13                         ' 'EXL99                         '
#  'COM04                         ' 'COM18                         '
#  'HLB99                         ' 'TAL04                         '
#  'SAE99                         ' 'COM80                         '
#  'LMP09                         ' 'URB99                         '
#  'COM02                         ' '4005' 'SUR02                         '
#  'RWY06                         ' '4003' '2004'
#  'LMP10                         ' 'COM11                         '
#  'LMP11                         ' '2013' '2599' '1001'
#  'LMP07                         ' '5002' '1002' '2003' '8001' '2001'
#  '2005' '5003' 'URB01                         '
#  'URB05                         ' '6001' '2502' '2011'
#  'LMP02                         ' '2002' 'LMP05                         '
#  '3002' 'COM70                         ' '1999'
#  'DLT05                         ' 'PEN90                         ' '4004'
#  '2016' '2505' '4002' '6002' '16135' '2503' '3005'
#  'FLD04                         ' '2008' '5004' '2604'
#  'EXL02                         ' '5005' 'DLT03                         '
#  'TAL07                         ' 'TAL99                         '
#  'EXL05                         ' '16131' '17100'
#  'SUR10                         ' '2501' '16133'
#  'TAL01                         ' 'TAL02                         ' '16137'
#  'TAL08                         ' '2512' '2516'
#  'SUR12                         ' 'SUR11                         ' '2515'
#  'SUR13                         ' '2514' 'SUR14                         '
#  '2508' 'IAE05                         ' '2507'
#  'PEN04                         ' '2511' 'PEN08                         '
#  '2509' '2504' '2510' '2517' '17200' '16121' '2513'
#  'LCP90                         ' '3006' '2012'
#  'TAL06                         ' '15999' '11103'
#  'PEN09                         ' '17300' 'LCP99                         '
#  'PEN10                         ' 'LMP90                         ' '4599'
#  '2603' '2006' '4009' '16134' '6003' 'RWY04                         '
#  '16132' 'IAI10                         ' 'LMP12                         '
#  '16138' '4504' '2605' '2607' '4502' '4016'
#  'PEN03                         ' '2007' '3999' '17001'
#  'IAI09                         ' 'LMP08                         '
#  'HLB80                         ' 'EXL03                         '
#  'RWY05                         ' 'IAI05                         '
#  'PEN99                         ' 'IAI08                         '
#  'IAI11                         ']
# --------------------------------------------------
# item_type
# [5 1 7 8 6 4 2 9 3]
# --------------------------------------------------
# bonus_group_code
# ['Trade          ' 'Professional   ']
# --------------------------------------------------
# environment_group_code
# ['S                             ' 'P                             '
#  'D                             ' 'Z                             '
#  'C                             ' 'M                             '
#  'R                             ' 'I                             '
#  'NA                            ']
# --------------------------------------------------
# technology_group_code
# ['SYLV                                    '
#  'NA                                      '
#  'PIER                                    ' '96' '219' '92' '214' '380'
#  '102' '123' '110' '98' '213' '580' '108' '999' '198'
#  'SCHR                                    ' '82' '140' '540'
#  'AUST                                    ' '480' '760' '460' '600' '520'
#  '998' '570' '280' '330' '220' '415' '340' '225'
#  'CSE                                     ' '565' '410' '560' '800' '680'
#  '320' '550' '400' '160' '440' '420' '500' '555' '360' '290' '780' '545'
#  '181' '240' '640' '820' '595' '300' '830' '70' '850' '86' '720' '740'
#  '310' 'FGDFT                                   ' '350' '206' '64'
#  'PNZ                                     ' '63'
#  'CROM                                    ' '100' '78' '207' '208' '76'
#  '211' '205' '85' '90' '68' '130'
#  'GLG                                     '
#  'INLIT                                   ' '72' '61' '880' '217' '215'
#  '80' '210' 'INZ                                     ' '250' '118' '66'
#  'PHANT                                   '
#  'DIGIN                                   ' '114' '112' '128' '88']
# --------------------------------------------------
# commission_group_code
# ['NET_SALES                     ' 'REBATE_EXEMPT_EOL             '
#  'REBATE_EXEMPT_TP              ']
# --------------------------------------------------
# reporting_classification
# ['Discontinuing' 'Continuing']
# --------------------------------------------------
# light_source
# ['Traditional' 'LED' 'Accessories']
# --------------------------------------------------
# warehouse_code
# ['Q1 ' 'V0 ' 'S0 ' 'T0 ' 'Q0 ' 'N0 ' 'KN0' 'W0 ' 'S1 ' 'Unk' 'GS0' 'GN0'
#  'CN0' 'CQ0' 'CV0' 'GW0' 'CS0' 'CW0' 'GQ0' 'AS0' 'CT0' 'CS1' 'CN1' 'CZ0'
#  'LW0' 'LQ0' 'LS1' 'LV0' 'LN9' 'LS0' 'FWE' 'EN0' 'FW2' 'JT0' 'FA1' 'FWA'
#  'FA2' '1N0' '1S0' '5N2' '5V0' '5S0' '5W0' '1V0' '1Q0' '1N1' '1W0' '1Q1'
#  '5Q0' '5T0' '5S1' '5N1' '1T0' '1S1' '5Q1' '1T1' 'BB1' '1N2' '1N3']
# --------------------------------------------------
# abc_class_code
# ['J' 'B' 'D' 'E' 'C' 'I' 'A' 'F' 'U' 'G']
# --------------------------------------------------
# abc_class_volume
# ['J' 'U' 'D' 'I' 'C' 'E' 'G' 'B' 'A' 'H']
# --------------------------------------------------
# business_chain_l1_code
# ['ELC' 'BPS' 'GEW' 'MED' 'AEG' 'UES' 'INTERCO   ' 'PTD' 'NLG' 'ZZZ       '
#  'NES' 'ZZ2       ' 'ZZ7       ' 'ZZ8       ' 'ZZ1       ' 'ZZ3       '
#  'ZZ6       ' 'CET       ' 'ZZ9       ' 'ZZ5       ' 'REP       '
#  'Z4500     ' 'Z2000     ' 'Z4000     ' 'Z4100     ' 'Z3200     '
#  'Z7500     ' 'Z8500     ' 'ZA900     ' 'ZI800     ' 'ZI900     '
#  'Z6100     ' 'ZI3000    ' 'ZI4500    ' 'ZI4000    ' 'ZI2000    '
#  'Z8100     ' 'Z2500     ' 'Z3500     ' 'Z6500     ' 'Z850339   '
#  'Z6800     ' 'Z850358   ' 'ZI3500    ' 'ZA800     ' 'Z9000     '
#  'ZA200     ' 'ZI80084   ']
# --------------------------------------------------
# business_chain_l1_name
# ['ElectraCorp Ltd' 'BrightPower Solutions' 'Global Electric Wholesalers'
#  'Metro Electrical Distributors' 'Aussie Energy Group'
#  'Unified Electrical Suppliers' 'InterGlobal Trading' 'PowerTools Direct'
#  'Nationwide Lighting Group' 'General Suppliers Pty'
#  'NextGen Electrical Solutions' 'Independent Retailers Association'
#  'UtilityWorks Group' 'EndUser Solutions' 'Builders Supply Network'
#  'ProLighting Specialists' 'Constructor Supplies' 'CetraPro Distributors'
#  'Corporate Builders Consortium' 'SalesPro Accounts'
#  'PowerHub Distribution' 'Ideal Electrical Solutions'
#  'Russell & Partners Electric' 'Stewart Electrical Wholesalers'
#  'CraneCo Distribution' 'DIY Supplies Network' 'Independent Traders Ltd'
#  'HeadOffice Electrical Group' 'Inlite Solutions' 'Inlite NZ Ltd'
#  'Beacon Lighting Supplies' 'CraneCo Old Branch'
#  'Russell & Radcliffe Electric' 'Corporate HQ Solutions'
#  'NextGen Electrical Group' 'Corys Energy Systems' 'MitrePro Suppliers'
#  'Active Electric Solutions' 'ITM Solutions Group' 'Electical Vista'
#  'Independent' 'Export' 'Electrical Active Supply']
# --------------------------------------------------
# contact_method_code
# ['NA                            ' 'FAX                           '
#  'NIM                           ' ... 'SPT                           '
#  'S                             ' 'SZA                           ']
# --------------------------------------------------
# salesperson_code
# ['T612' 'P345' 'T504' 'P347' 'P342' 'P344' 'T408' 'P237' 'T203' 'T204'
#  'P248' 'T215' 'P415' 'P218' 'P350' 'T432' 'R806' 'T200' 'T220' 'T431'
#  'T428' 'P515' 'P107' 'T607' 'T312' 'T400' 'T207' 'T418' 'T300' 'T405'
#  'T206' 'T302' 'P506' 'P326' 'T602' 'T603' 'T606' 'P600' 'P399' 'T304'
#  'R327' 'P421' 'P500' 'T217' 'T111' 'T306' 'P327' 'P225' 'P213' 'P427'
#  'T503' 'T510' 'P300' 'P513' 'T303' 'T205' 'R520' 'T404' 'P200' 'T318'
#  'P601' 'T508' 'P205' 'P331' 'P602' 'P245' 'T505' 'T501' 'P306' 'T227'
#  'T414' 'T500' 'P202' 'T407' 'T228' 'T406' 'P419' 'P400' 'T214' 'R266'
#  'R620' 'T413' 'T600' 'P227' 'P310' 'P404' 'R338' 'R635' 'T310' 'T314'
#  'R622' 'P208' 'P134' 'P236' 'R300' 'P230' 'T225' 'T222' 'P304' 'T502'
#  'T305' 'T401' 'T319' 'T308' 'R274' 'T513' 'R232' 'P246' 'T209' 'P516'
#  'T415' 'P611' 'P412' 'T231' 'P504' 'P224' 'P211' 'T604' 'T229' 'P221'
#  'P303' 'T403' 'P127' 'P214' 'P430' 'P417' 'T226' 'R436' 'T420' 'P239'
#  'RM34' 'RM21' 'RM89' 'RM73' 'RM47' 'RM44' 'RM79' 'RM92' 'RM84' 'RM20'
#  'RM93' 'RM82' 'RM11' 'RM22' 'RM96' 'RM76' 'RM98' 'RM87' 'RM18' 'RM15'
#  'T411' 'RM91' 'RM99' 'T224' 'RM88' 'RM77' 'RM58' 'RM05' 'RM01' 'RM62'
#  'RM90' 'RM94' 'T906' 'T909' 'RC12' 'RSP1' 'T230' 'T316' 'RM55' 'T211'
#  'RM02' 'T210' 'RSP2' 'P121' 'T317' 'T218' 'T506' 'T208' 'T221' 'RC17'
#  'P428' 'T410' 'R727' 'RC22' 'P599' 'T512' 'RB03' 'R605' 'R400' 'R500'
#  'R220' 'RZ81' 'RZ22' 'RZ99' 'RE04' 'RZ85' 'RZ84' 'RZ65' 'RZ24' 'RZ52'
#  'R999' 'RZ82' 'RB05' 'RZ70' 'RZ63' 'RZ83' 'RZ61' 'RZ02' 'RZ71' 'IN06'
#  'IN03' 'IN02' 'RZ62' 'IN04' 'RZ98' 'IN07' 'IN01' 'RZ54' 'IN05' 'RZ64'
#  'RM04' 'RE06' 'RE01' 'RZ72' 'P316' 'P335' 'R987' 'RV01' 'P507' 'RZ76'
#  'P423' 'IN10' 'P338' 'P207' 'P219' 'P605' 'P206' 'P503' 'P341' 'P349'
#  'P426' 'IN09' 'P315' 'T213' 'P510' 'P235' 'P943' 'I375' 'R441' 'R640'
#  'P223' 'P312' 'P606' 'RZ38' 'P346' 'RZ97' 'DG06' 'P348' 'R625' 'RA01'
#  'R260' 'DG09' 'RZ28' 'RZ04' 'RE08' 'RZ05' 'R449' 'P609' 'RT17' 'RT18'
#  'DG07']
# --------------------------------------------------
# order_type_code
# ['NOR' 'EDI' 'CDG' 'PRO' 'NOS' 'CRR' 'EXP' 'EDS' 'CSH' 'PRD' 'CRD' 'NOH'
#  'COP' 'OBS' 'MIN' 'COA' 'PSA' 'PPD' 'WDC' 'PMO' 'CPR' 'CRP' 'PM0' 'PGS'
#  'SPL' 'AES' 'ZCG' 'ZCR' 'SPC' 'ZOP' 'ZC2' '5TN' 'PUP' 'PPO' 'ZD3' 'CSO'
#  'PME']
# --------------------------------------------------
# market_segment
# ['Commercial & Industrial']
# --------------------------------------------------
# value_sales
# [218.4   38.28  40.2  ... 150.67 425.9  232.19]
# --------------------------------------------------
# value_cost
# [178.1976  25.4568  12.7284 ...  96.8759 681.45    58.7915]
# --------------------------------------------------
# value_quantity
# [  84.   12.    6. ... 2389. -188. 1664.]
# --------------------------------------------------
# value_price_adjustment
# [0 1]
# --------------------------------------------------
# currency
# ['AUD' 'USD' 'AUS' 'NZD' '   ' 'EUR']
# --------------------------------------------------
# item_source_class
# [nan]
# --------------------------------------------------
# invoice_number
# [2217887 2185745 2217807 ... 2423962 2423898 2383667]
# --------------------------------------------------
# line_number
# [  1   2   3  -2  -3  -7  -6   9  -1 -11 -20   4  -5 -16  -8  -4 -17 -13
#  -12  -9 -18 -10   5   7 -19 -21 -22 -14 -15 -24   6 -23 -26   0 -28 -27
#  -33 -32 -29 -30 -31 -25 -40 -35 -36 -34 -37 -38 -39  14  12   8  11 -56
#   13  10 -47 -48 -49 -50 -41 -66 -67 -68 -61 -62 -63 -64 -65 -69 -70 -51
#  20131025 20131212 20131129 20130916 20131211 20131105 20131022 20131216
#  20131120 20130717 20130710 20130730 20130917 20131213 20130821 20131114
#  20131110 20130724 20130704 20131103 20131209 20130829 20130806 20130702
#  20131126 20131203 20130725 20130816 20131002 20131106 20130711 20130919
#  20131125 20131003 20130808 20131112 20130912 20131030 20130823 20130822
#  20130726 20131028 20131220 20131127 20131018 20131026 20131109 20131101
#  20131223 20131102 20131227 20131230 20131201 20131123 20131226 20130907
#  20131130 20131214 20130804 20130818 20131224 20130707 20131116 20130921
#  20130831 20131005 20130922 20131012 20130713 20130720 20130908 20130706
#  20090326 20131117 20130824 20131222]
# --------------------------------------------------
# dss_update_time
# ['49:58.7']
# --------------------------------------------------

# %%
print("Unique values in:")

for col in data.columns:
    uniques = data[col].value_counts()
    print(f"{col} is: {uniques}")
# Out:
# Unique values in:
# accounting_date is: accounting_date
# 20130430    8132
# 20120202    5810
# 20120703    5740
# 20120403    5713
# 20130528    5674
#             ...
# 20130831       2
# 20130329       1
# 20130106       1
# 20120728       1
# 20120630       1
# Name: count, Length: 543, dtype: int64
# fiscal_year is: fiscal_year
# 2013    978202
# 2012    537030
# 2014    473150
# Name: count, dtype: int64
# fiscal_month is: fiscal_month
# 11    213313
# 1     194771
# 2     184176
# 12    176517
# 4     166941
# 9     163786
# 10    161719
# 3     160993
# 8     160699
# 5     153317
# 7     139023
# 6     113127
# Name: count, dtype: int64
# calendar_year is: calendar_year
# 2012    1037205
# 2013     951177
# Name: count, dtype: int64
# calendar_month is: calendar_month
# 5     213313
# 7     194771
# 8     184176
# 6     176517
# 10    166941
# 3     163786
# 4     161719
# 9     160993
# 2     160699
# 11    153317
# 1     139023
# 12    113127
# Name: count, dtype: int64
# calendar_day is: calendar_day
# 5     74578
# 19    73692
# 18    73065
# 13    71833
# 4     71395
# 17    70557
# 2     70473
# 20    69508
# 3     69283
# 6     68698
# 12    68343
# 16    67901
# 11    65421
# 23    65070
# 8     64598
# 14    64458
# 15    64142
# 10    64104
# 30    63671
# 22    63382
# 21    63172
# 9     63131
# 27    63079
# 7     62451
# 24    60021
# 26    58730
# 28    56986
# 25    55290
# 1     54016
# 29    52460
# 31    34874
# Name: count, dtype: int64
# company_code is: company_code
# 205    1414918
# 101     348021
# 950     116637
# 220      83862
# 100      20097
# 140       3632
# 240        696
# 510        356
# 120         98
# 170         65
# Name: count, dtype: int64
# customer_code is: customer_code
# 234750001     45708
# 234750001     16136
# 525200100      9502
# 471000829      6730
# 901000100      6437
#               ...
# Z25000020         1
# 505510010         1
# 502400300         1
# 516000600         1
# 800610100         1
# Name: count, Length: 7241, dtype: int64
# customer_district_code is: customer_district_code
# 300    429358
# 200    425511
# 400    349656
# 500    179161
# 600    167061
# 720     89858
# 410     72774
# 210     70284
# 540     59610
# 310     34894
# 710     29103
# 530     27731
# 510     24627
# 535     23254
# 520      5446
# 545        48
# 100         6
# Name: count, dtype: int64
# item_code is: item_code
# S10                               7465
# 25550                             6900
# PND236EL                          6764
# 15892                             6331
# 25335                             6244
#                                   ...
# DT2021480W                           1
# DOT24002HFA6455                      1
# DT2022421A                           1
# GT5228D4KIT3                         1
# 0.90811.00-910                       1
# Name: count, Length: 36738, dtype: int64
# business_area_code is: business_area_code
# LMP                               808688
# SUR                               405479
# COM                               201268
# OTH                               187247
# DLT                               103441
# FLD                                91437
# TRO                                33757
# TAL                                33158
# SAE                                29021
# URB                                26906
# RWY                                19288
# HLB                                18168
# PEN                                 8847
# LCP                                 6737
# 980                                 5502
# EXL                                 2237
# 970                                 1458
# 999                                 1266
# 940                                 1185
# 920                                 1006
# 985                                  674
# 910                                  505
# 950                                  418
# IAI                                  226
# 945                                  181
# 960                                  157
# IAE                                   99
# 930                                   26
# Name: count, dtype: int64
# item_group_code is: item_group_code
# 999                               187247
# SUR04001                           96468
# COM99001                           83903
# LMP02001                           59578
# LMP03001                           50246
#                                    ...
# CINST900                               1
# 231                                    1
# CSIGN115                               1
# LG900000                               1
# IAI11001                               1
# Name: count, Length: 614, dtype: int64
# item_class_code is: item_class_code
# LMP05                             200724
# 14001                             187985
# LMP04                             186966
# LMP03                             138734
# LMP01                             124775
#                                    ...
# 17300                                  1
# 4016                                   1
# IAI05                                  1
# IAI08                                  1
# IAI11                                  1
# Name: count, Length: 204, dtype: int64
# item_type is: item_type
# 7    952028
# 5    474503
# 6    254240
# 1    190741
# 9     74253
# 4     22734
# 8      7765
# 2      7590
# 3      4528
# Name: count, dtype: int64
# bonus_group_code is: bonus_group_code
# Trade              1652568
# Professional        335814
# Name: count, dtype: int64
# environment_group_code is: environment_group_code
# C                                 764544
# S                                 493145
# P                                 448687
# R                                 192761
# Z                                  88008
# D                                    548
# I                                    382
# NA                                   162
# M                                    145
# Name: count, dtype: int64
# technology_group_code is: technology_group_code
# 78                                          275724
# CROM                                        273233
# NA                                          211248
# SYLV                                        185491
# 219                                         165018
#                                              ...
# PHANT                                            3
# 88                                               2
# 66                                               1
# 114                                              1
# 112                                              1
# Name: count, Length: 103, dtype: int64
# commission_group_code is: commission_group_code
# NET_SALES                         1893377
# REBATE_EXEMPT_EOL                   91983
# REBATE_EXEMPT_TP                     3022
# Name: count, dtype: int64
# reporting_classification is: reporting_classification
# Discontinuing    1421405
# Continuing        566977
# Name: count, dtype: int64
# light_source is: light_source
# Traditional    1382270
# Accessories     455656
# LED             150456
# Name: count, dtype: int64
# warehouse_code is: warehouse_code
# 5N2    549104
# CN0    201173
# Unk    197048
# 5V0    100320
# 5Q0     88295
# 5W0     82621
# 5S0     80006
# FA1     68742
# 1N1     60761
# 5N1     48197
# 1N0     43314
# V0      40941
# FWE     34452
# LN9     33383
# N0      30613
# 1V0     30450
# 1Q0     27996
# CS0     23061
# Q0      22310
# CW0     20955
# LV0     20833
# KN0     20093
# 1W0     19954
# LQ0     16317
# W0      15303
# S0      13876
# CQ0     11941
# 1S0      9016
# CV0      8673
# Q1       7843
# 5Q1      7747
# LW0      7258
# 5S1      6468
# FWA      5480
# FW2      4137
# FA2      3827
# 5T0      3744
# 1Q1      3724
# GN0      3500
# T0       3478
# S1       3451
# 1S1      2316
# LS0      1969
# 1T0       612
# EN0       570
# CN1       522
# CS1       516
# LS1       494
# JT0       353
# CZ0       109
# CT0       105
# GW0        99
# 1T1        97
# BB1        95
# AS0        65
# GS0        30
# 1N2        14
# 1N3         9
# GQ0         2
# Name: count, dtype: int64
# abc_class_code is: abc_class_code
# J    661307
# A    292947
# D    215650
# B    213357
# U    197048
# G    190481
# C    140771
# I     43155
# E     26625
# F      7041
# Name: count, dtype: int64
# abc_class_volume is: abc_class_volume
# J    1561088
# U     197048
# E     193509
# D      10509
# B       8446
# A       7051
# I       5830
# C       2691
# H       2117
# G         93
# Name: count, dtype: int64
# business_chain_l1_code is: business_chain_l1_code
# MED           439624
# ZZ1           280592
# BPS           173564
# NES           161612
# ZZ2           158923
# ELC           102303
# INTERCO        89805
# NLG            88015
# ZZ3            85578
# AEG            72496
# ZZZ            62580
# ZZ8            47136
# UES            46931
# GEW            27890
# Z7500          25830
# Z4000          24143
# Z6500          18575
# Z8500          14167
# ZZ9             9438
# ZZ7             9216
# PTD             9175
# Z4500           6138
# ZZ6             5048
# Z2000           4679
# Z3200           4034
# Z4100           3798
# Z6100           3758
# Z3500           3025
# ZI900           2454
# ZZ5             1858
# ZI800           1655
# Z850339         1270
# ZA900            698
# ZI4500           522
# ZI2000           423
# ZI4000           367
# Z6800            309
# CET              249
# Z9000            185
# ZA200            112
# Z8100             66
# REP               49
# ZI3000            41
# Z850358           22
# ZI3500            18
# Z2500              7
# ZA800              2
# ZI80084            2
# Name: count, dtype: int64
# business_chain_l1_name is: business_chain_l1_name
# Metro Electrical Distributors        439624
# Builders Supply Network              280592
# BrightPower Solutions                173564
# NextGen Electrical Solutions         161612
# Independent Retailers Association    158923
# ElectraCorp Ltd                      102303
# InterGlobal Trading                   89805
# Nationwide Lighting Group             88015
# ProLighting Specialists               85578
# Aussie Energy Group                   72496
# General Suppliers Pty                 64438
# EndUser Solutions                     47136
# Unified Electrical Suppliers          46931
# Global Electric Wholesalers           27890
# DIY Supplies Network                  25830
# Russell & Partners Electric           24143
# MitrePro Suppliers                    18575
# Independent Traders Ltd               14167
# Corporate Builders Consortium          9438
# UtilityWorks Group                     9216
# PowerTools Direct                      9175
# PowerHub Distribution                  6660
# Ideal Electrical Solutions             5214
# Constructor Supplies                   5048
# CraneCo Distribution                   4034
# Stewart Electrical Wholesalers         3798
# Beacon Lighting Supplies               3758
# Corys Energy Systems                   3043
# Inlite NZ Ltd                          2454
# Inlite Solutions                       1655
# Active Electric Solutions              1270
# HeadOffice Electrical Group             698
# Russell & Radcliffe Electric            367
# ITM Solutions Group                     309
# CetraPro Distributors                   249
# Export                                  185
# Corporate HQ Solutions                   66
# SalesPro Accounts                        49
# CraneCo Old Branch                       41
# Electical Vista                          22
# NextGen Electrical Group                  7
# Independent                               2
# Electrical Active Supply                  2
# Name: count, dtype: int64
# contact_method_code is: contact_method_code
# NA                                1901893
# FAX                                 41940
# EDI                                  4454
# TBA                                  1789
# Z38                                  1748
#                                    ...
# WY0                                     1
# D4B                                     1
# LE1                                     1
# PCN                                     1
# SZA                                     1
# Name: count, Length: 1665, dtype: int64
# salesperson_code is: salesperson_code
# T300    97193
# P342    80938
# T909    80748
# P344    78763
# T215    70392
#         ...
# RM77        1
# RB03        1
# RM55        1
# RM02        1
# DG07        1
# Name: count, Length: 271, dtype: int64
# order_type_code is: order_type_code
# NOR    1612532
# EDI     126289
# CRD      47717
# CRR      45809
# PRO      29129
# PRD      20973
# PUP      19756
# NOH      16501
# PPO      13222
# PMO      12401
# CDG      12283
# AES       7195
# EXP       5794
# SPC       5362
# NOS       2536
# CSH       2048
# ZCG       1931
# ZCR       1415
# COP       1277
# 5TN        781
# MIN        735
# CPR        616
# PSA        599
# EDS        443
# CRP        304
# PME        243
# COA        215
# SPL        147
# PPD         54
# OBS         39
# PGS         13
# WDC         10
# ZOP          5
# PM0          4
# CSO          2
# ZC2          1
# ZD3          1
# Name: count, dtype: int64
# market_segment is: market_segment
# Commercial & Industrial    1988382
# Name: count, dtype: int64
# value_sales is: value_sales
# 0.00       22300
# 5.50        8806
# 5.70        8621
# 18.00       7103
# 48.00       6210
#            ...
# 9825.92        1
# 1359.85        1
# 273.97         1
# 472.82         1
# 232.19         1
# Name: count, Length: 125221, dtype: int64
# value_cost is: value_cost
#  0.0000      50113
#  12.7284      7064
#  25.4568      6929
#  60.9000      5726
#  36.5400      4576
#              ...
#  816.3844        1
#  18.3172         1
#  18.5387         1
# -18.6334         1
#  58.7915         1
# Name: count, Length: 324347, dtype: int64
# value_quantity is: value_quantity
# 10.0      264873
# 2.0       218419
# 1.0       210935
# 4.0       140615
# 20.0      140108
#            ...
# 1436.0         1
# 728.0          1
# 1934.0         1
# 981.0          1
# 1664.0         1
# Name: count, Length: 2291, dtype: int64
# value_price_adjustment is: value_price_adjustment
# 0    1939831
# 1      48551
# Name: count, dtype: int64
# currency is: currency
# AUD    1582755
# AUS     287814
# NZD     116633
# USD        675
# EUR        503
#              2
# Name: count, dtype: int64
# item_source_class is: Series([], Name: count, dtype: int64)
# invoice_number is: invoice_number
# 7002085    897
# 7002043    776
# 7002264    677
# 7002261    629
# 7002259    548
#           ...
# 2245788      1
# 2259628      1
# 2241648      1
# 2245889      1
# 2383667      1
# Name: count, Length: 619292, dtype: int64
# line_number is: line_number
#  0     1190970
#  1      589952
#  2       93235
# -1       36315
#  3       21822
#         ...
# -90          1
# -91          1
#  48          1
#  47          1
#  49          1
# Name: count, Length: 142, dtype: int64
# invoice_date is: invoice_date
# 20130430    8132
# 20120202    5810
# 20120703    5740
# 20120403    5713
# 20130528    5674
#             ...
# 20130831       2
# 20130329       1
# 20130106       1
# 20120728       1
# 20120630       1
# Name: count, Length: 543, dtype: int64
# customer_order_number is: customer_order_number
# 263824     301
# 258450     277
# 257823     265
# 264627     264
# 265611     262
#           ...
# 2928391      1
# 2923939      1
# 2894584      1
# 2918301      1
# 3024473      1
# Name: count, Length: 659748, dtype: int64
# order_date is: order_date
# 20120620    6232
# 20120501    6021
# 20130701    5934
# 20130422    5919
# 20130515    5910
#             ...
# 20110601       1
# 20101210       1
# 20110627       1
# 20110525       1
# 20111001       1
# Name: count, Length: 804, dtype: int64
# dss_update_time is: dss_update_time
# 49:58.7    1988382
# Name: count, dtype: int64

# %%
# Check Statstical Summary of the dataset

data.describe()
# Out:
#        accounting_date   fiscal_year  fiscal_month  calendar_year  \
# count     1.988382e+06  1.988382e+06  1.988382e+06   1.988382e+06
# mean      2.012544e+07  2.012968e+03  6.524841e+00   2.012478e+03
# std       5.011222e+03  7.120459e-01  3.620881e+00   4.995319e-01
# min       2.012010e+07  2.012000e+03  1.000000e+00   2.012000e+03
# 25%       2.012062e+07  2.012000e+03  3.000000e+00   2.012000e+03
# 50%       2.012121e+07  2.013000e+03  7.000000e+00   2.012000e+03
# 75%       2.013062e+07  2.013000e+03  1.000000e+01   2.013000e+03
# max       2.013123e+07  2.014000e+03  1.200000e+01   2.013000e+03
#
#        calendar_month  calendar_day  company_code  customer_district_code  \
# count    1.988382e+06  1.988382e+06  1.988382e+06            1.988382e+06
# mean     6.398914e+00  1.546221e+01  2.300125e+02            3.817729e+02
# std      3.251493e+00  8.684856e+00  1.843121e+02            1.527461e+02
# min      1.000000e+00  1.000000e+00  1.000000e+02            1.000000e+02
# 25%      4.000000e+00  8.000000e+00  2.050000e+02            3.000000e+02
# 50%      6.000000e+00  1.500000e+01  2.050000e+02            4.000000e+02
# 75%      9.000000e+00  2.300000e+01  2.050000e+02            5.000000e+02
# max      1.200000e+01  3.100000e+01  9.500000e+02            7.200000e+02
#
#           item_type   value_sales    value_cost  value_quantity  \
# count  1.988382e+06  1.988382e+06  1.988382e+06    1.988382e+06
# mean   5.835392e+00  4.098476e+02  2.638138e+02    2.718023e+01
# std    1.888795e+00  2.935179e+03  2.050514e+03    3.294667e+02
# min    1.000000e+00 -7.935420e+05 -1.414695e+05   -4.500000e+04
# 25%    5.000000e+00  2.300000e+01  9.381000e+00    2.000000e+00
# 50%    7.000000e+00  6.750000e+01  3.107000e+01    6.000000e+00
# 75%    7.000000e+00  1.977000e+02  1.019106e+02    2.000000e+01
# max    9.000000e+00  7.935420e+05  7.776692e+05    1.050000e+05
#
#        value_price_adjustment  item_source_class  invoice_number  \
# count            1.988382e+06                0.0    1.988382e+06
# mean             2.441734e-02                NaN    1.260426e+06
# std              1.543410e-01                NaN    1.355150e+06
# min              0.000000e+00                NaN    0.000000e+00
# 25%              0.000000e+00                NaN    6.564320e+05
# 50%              0.000000e+00                NaN    7.496270e+05
# 75%              0.000000e+00                NaN    2.214222e+06
# max              1.000000e+00                NaN    7.003023e+06
#
#         line_number  invoice_date    order_date
# count  1.988382e+06  1.988382e+06  1.988382e+06
# mean   3.612757e-01  2.012544e+07  2.012535e+07
# std    1.718996e+00  5.011222e+03  5.107654e+03
# min   -9.200000e+01  2.012010e+07  2.009033e+07
# 25%    0.000000e+00  2.012062e+07  2.012062e+07
# 50%    0.000000e+00  2.012121e+07  2.012120e+07
# 75%    1.000000e+00  2.013062e+07  2.013062e+07
# max    4.900000e+01  2.013123e+07  2.013123e+07

# %%
data.shape
# Out:
# (1988382, 41)

# %% [markdown]
# ### **B. Handling Duplicates**

# %% [markdown]
# The selected columns for identifying duplicates were chosen based on their role in uniquely defining each transaction:
#
# * invoice_number and line_number: These ensure each invoice and its line items are treated as distinct entries, even within the same invoice.
# * customer_code: Differentiates transactions by customer, preventing overlap between invoices associated with different clients.
# * item_code: Distinguishes different products or services within the same invoice.
# * invoice_date: Ensures that transactions occurring on different dates are treated separately.
# * value_sales, value_cost, and value_quantity: Capture the financial details of each transaction, ensuring that differences in sales, costs, or quantities prevent incorrect duplicate identification.
#
# These columns collectively capture the "who," "what," "when," and financial aspects of the transaction, allowing for accurate identification and removal of true duplicates.

# %%
# Check for duplicates based on specific columns
duplicate_rows = data.duplicated(subset=["invoice_number", "line_number", "customer_code", 
                                         "item_code", "value_sales", "value_cost", "value_quantity", "invoice_date"])

# Display the number of duplicate rows found & initial shape of  the dataset
print(f"Number of duplicate rows based on selected columns: {duplicate_rows.sum()}")
print(f"Data shape before removing duplicates: {data.shape}")
# Out:
# Number of duplicate rows based on selected columns: 8962
# Data shape before removing duplicates: (1988382, 41)

# %%
# Remove duplicates based on these columns, keeping the first occurrence
data = data.drop_duplicates(subset=["invoice_number", "line_number", "customer_code", 
                                    "item_code", "value_sales", "value_cost", "value_quantity", "invoice_date"], keep="first")

# Verify the shape of the data after removing duplicates
print(f"Data shape after removing duplicates: {data.shape}")
# Out:
# Data shape after removing duplicates: (1979420, 41)

# %% [markdown]
# ### **C. Handling Columns with Missing Values or Irrelevant Information**

# %% [markdown]
# #### I. Handle Missing Values

# %%
# Check for missing values in each feature
missing_values = data.isnull().sum()

print(missing_values)
# Out:
# accounting_date                   0
# fiscal_year                       0
# fiscal_month                      0
# calendar_year                     0
# calendar_month                    0
# calendar_day                      0
# company_code                      0
# customer_code                     0
# customer_district_code            0
# item_code                         0
# business_area_code                0
# item_group_code                   0
# item_class_code                   0
# item_type                         0
# bonus_group_code                  0
# environment_group_code            0
# technology_group_code             0
# commission_group_code             0
# reporting_classification          0
# light_source                      0
# warehouse_code                    0
# abc_class_code                    0
# abc_class_volume                  0
# business_chain_l1_code            0
# business_chain_l1_name            0
# contact_method_code               0
# salesperson_code                  0
# order_type_code                   0
# market_segment                    0
# value_sales                       0
# value_cost                        0
# value_quantity                    0
# value_price_adjustment            0
# currency                          0
# item_source_class           1979420
# invoice_number                    0
# line_number                       0
# invoice_date                      0
# customer_order_number             0
# order_date                        0
# dss_update_time                   0
# dtype: int64

# %% [markdown]
# **Item_source_class** presents 100% values being missed within the column. This requires removing them (instead of imputing).

# %%
# Drop "item_source_class"

data = data.drop(columns = "item_source_class")

# %%
# Re-check datashape, the columns should have 40 now
data.shape
# Out:
# (1979420, 40)

# %% [markdown]
# #### II. Handle Irrelevant Information

# %% [markdown]
# Columns that might not add value to the analysis or are redundant can be dropped.
# * dss_update_time: This is a timestamp for the system's internal update, which might not be relevant to our analysis.
# * The calendar_day column: Since we already have complete date information in order_date and invoice_date, calendar_day is redundant and does not provide additional value on its own.
#
# Potential Redundency:
# * calendar_year, calendar_month, calendar_day: These are redundant since we already have a combined date field like invoice_date and order_date.
# * fiscal_year, fiscal_month: These might also be redundant if we only need one time reference (like the calendar year).
#
# **Retain both fiscal and calendar date fields to cover both operational (order and invoice dates) and financial (fiscal year/month) perspectives for comprehensive analysis.**

# %%
# Drop "dss_update_time", "calendar_day" columns

data = data.drop(columns = ["dss_update_time", "calendar_day"])

# %% [markdown]
# #### III. Handle Mis-spelling Data & Other Potential Inconsistencies

# %% [markdown]
# ##### *A) Order Type Codes*

# %%
# Check number of unique values in this column

data["order_type_code"].value_counts()
# Out:
# order_type_code
# NOR    1608933
# EDI     126208
# CRR      45732
# CRD      43827
# PRO      29019
# PRD      20842
# PUP      19751
# NOH      16416
# PPO      13213
# PMO      12106
# CDG      12070
# AES       7190
# EXP       5773
# SPC       5162
# NOS       2531
# CSH       2044
# ZCG       1929
# ZCR       1410
# COP       1271
# MIN        732
# 5TN        617
# CPR        606
# PSA        566
# EDS        442
# CRP        298
# PME        242
# COA        215
# SPL        147
# PPD         53
# OBS         39
# PGS         13
# WDC         10
# ZOP          5
# PM0          4
# CSO          2
# ZC2          1
# ZD3          1
# Name: count, dtype: int64

# %% [markdown]
# The frequency count shows that PME appears 242 times, while PMO appears 12,106 times. Given the similarity between PME and PMO, it is very likely that PME is a misspelling of PMO. The lower occurrence of PME compared to PMO strongly supports the idea that it is a data entry error.
#
# * PMO appears 12,106 times, and it's listed as a valid order type in the README.
# * PM0 (with a zero) appears 4 times, but this is marked as a "Do Not Use" code in the README.
# * PME appears 242 times, and it does not exist in the README.
#
# Given this, PME is more likely a typo for PMO (with the letter "O"), rather than PM0 (with a zero), since PMO has significantly higher frequency and is a valid code, while PM0 is marked as "Do Not Use".

# %%
# Check total unique values in this column

data["order_type_code"].nunique()
# Out:
# 37

# %%
# Replace "PME" with "PMO"

data["order_type_code"].replace("PME", "PMO", inplace = True)

# %%
# Re-check total unique values in this column

data["order_type_code"].nunique()
# Out:
# 36

# %% [markdown]
# ##### *B) abc_class_volume & abc_class_code*

# %% [markdown]
# Labels of these columns in the Metadata (README) match those in the dataset.

# %%
data["abc_class_volume"].value_counts()
# Out:
# abc_class_volume
# J    1553827
# U     196758
# E     192390
# D      10365
# B       8424
# A       7022
# I       5810
# C       2624
# H       2108
# G         92
# Name: count, dtype: int64

# %%
data["abc_class_code"].value_counts()
# Out:
# abc_class_code
# J    658398
# A    291966
# D    214960
# B    212825
# U    196758
# G    187964
# C    139954
# I     43033
# E     26532
# F      7030
# Name: count, dtype: int64

# %% [markdown]
# ##### *C) Warehouse Codes*

# %%
# Check number of unique values in this column

data["warehouse_code"].value_counts()
# Out:
# warehouse_code
# 5N2    546020
# CN0    199251
# Unk    196758
# 5V0    100253
# 5Q0     88177
# 5W0     82553
# 5S0     79843
# FA1     68579
# 1N1     60405
# 5N1     47507
# 1N0     42849
# V0      40925
# FWE     34344
# LN9     33304
# N0      30565
# 1V0     30399
# 1Q0     27952
# CS0     22986
# Q0      22255
# CW0     20941
# LV0     20817
# 1W0     19904
# KN0     19734
# LQ0     16295
# W0      15288
# S0      13864
# CQ0     11911
# 1S0      8989
# CV0      8650
# Q1       7832
# 5Q1      7740
# LW0      7251
# 5S1      6463
# FWA      5279
# FW2      4133
# FA2      3823
# 5T0      3736
# 1Q1      3717
# T0       3478
# S1       3451
# GN0      3411
# 1S1      2315
# LS0      1959
# 1T0       612
# EN0       568
# CS1       516
# CN1       505
# LS1       493
# JT0       198
# CZ0       108
# CT0       105
# GW0        98
# 1T1        96
# BB1        95
# AS0        65
# GS0        30
# 1N2        14
# 1N3         9
# GQ0         2
# Name: count, dtype: int64

# %% [markdown]
# **Suggested Actions**
# 1. Handling Unk: If Unk represents "Unknown," consider either keeping it for cases where the warehouse is genuinely unknown or explore ways to fill this missing information if possible.
# 2. Inactive Codes (like CN0): Since codes like CN0 are marked as inactive ("NO LONGER ACTIVE"), it might be useful to investigate if they represent outdated data. You can mark them as historical or filter them out, depending on your business needs.

# %%
# Check total unique values in this column

data["warehouse_code"].nunique()
# Out:
# 59

# %% [markdown]
# The following codes are present but were not initially listed in the README:
# * 1N2 – 14 occurrences
# * 1N3 – 9 occurrences
# * BB1 – 95 occurrences
#
# Given the very low frequency of these undocumented codes (1N2, 1N3, and BB1) in a dataset of nearly 2 million rows, it is a reasonable decision to drop them. Their impact on the overall dataset is minimal, and since they are not documented, it's safer to assume they could be erroneous.

# %%
# Remove rows with values in warehouse codes that are not in the README

data = data.drop(data[data["warehouse_code"].isin(["1N2", "1N3", "BB1"])].index)

# %% [markdown]
# ##### *D) Environment Group Codes*

# %%
# Check number of unique values in this column

data["environment_group_code"].value_counts()
# Out:
# environment_group_code
# C                                 761954
# S                                 492555
# P                                 446314
# R                                 189885
# Z                                  87437
# D                                    468
# I                                    382
# NA                                   162
# M                                    145
# Name: count, dtype: int64

# %% [markdown]
# ##### *E) Business Area Code*

# %%
# Check number of unique values in this column

data["business_area_code"].value_counts()
# Out:
# business_area_code
# LMP                               807089
# SUR                               402303
# COM                               199412
# OTH                               186764
# DLT                               103225
# FLD                                90633
# TRO                                33594
# TAL                                33033
# SAE                                28869
# URB                                26849
# RWY                                19262
# HLB                                18126
# PEN                                 8830
# LCP                                 6426
# 980                                 5494
# EXL                                 2229
# 970                                 1451
# 999                                 1255
# 940                                 1177
# 920                                 1003
# 985                                  671
# 910                                  505
# 950                                  418
# IAI                                  226
# 945                                  181
# 960                                  152
# IAE                                   99
# 930                                   26
# Name: count, dtype: int64

# %% [markdown]
# ##### *F) Customer District Code*

# %%
# Check number of unique values in this column

data["customer_district_code"].value_counts()
# Out:
# customer_district_code
# 300    428956
# 200    424709
# 400    349078
# 500    178573
# 600    166870
# 720     88245
# 410     72665
# 210     70189
# 540     59475
# 310     34838
# 530     27665
# 710     24954
# 510     24610
# 535     23176
# 520      5245
# 545        48
# 100         6
# Name: count, dtype: int64

# %%
# Remove rows with customer district code of 100

data = data.drop(data[data["customer_district_code"] == 100].index)

# %%
data.head(10).transpose()
# Out:
#                                                                  0  \
# accounting_date                                           20120509
# fiscal_year                                                   2012
# fiscal_month                                                    11
# calendar_year                                                 2012
# calendar_month                                                   5
# company_code                                                   101
# customer_code                                            411800601
# customer_district_code                                         410
# item_code                           GENIE8WWWBC
# business_area_code                  LMP
# item_group_code                     LMP01008
# item_class_code                     LMP01
# item_type                                                        5
# bonus_group_code                                   Trade
# environment_group_code              S
# technology_group_code     SYLV
# commission_group_code               NET_SALES
# reporting_classification                             Discontinuing
# light_source                                           Traditional
# warehouse_code                                                 Q1
# abc_class_code                                                   J
# abc_class_volume                                                 J
# business_chain_l1_code                                         ELC
# business_chain_l1_name                             ElectraCorp Ltd
# contact_method_code                 NA
# salesperson_code                                              T612
# order_type_code                                                NOR
# market_segment                             Commercial & Industrial
# value_sales                                                  218.4
# value_cost                                                178.1976
# value_quantity                                                84.0
# value_price_adjustment                                           0
# currency                                                       AUD
# invoice_number                                             2217887
# line_number                                                      1
# invoice_date                                              20120509
# customer_order_number                                      2865354
# order_date                                                20120509
#
#                                                                  1  \
# accounting_date                                           20120216
# fiscal_year                                                   2012
# fiscal_month                                                     8
# calendar_year                                                 2012
# calendar_month                                                   2
# company_code                                                   101
# customer_code                                            361000403
# customer_district_code                                         300
# item_code                           GENIE8WWWBC
# business_area_code                  LMP
# item_group_code                     LMP01008
# item_class_code                     LMP01
# item_type                                                        5
# bonus_group_code                                   Trade
# environment_group_code              S
# technology_group_code     SYLV
# commission_group_code               NET_SALES
# reporting_classification                             Discontinuing
# light_source                                           Traditional
# warehouse_code                                                 V0
# abc_class_code                                                   J
# abc_class_volume                                                 J
# business_chain_l1_code                                         BPS
# business_chain_l1_name                       BrightPower Solutions
# contact_method_code                 NA
# salesperson_code                                              P345
# order_type_code                                                NOR
# market_segment                             Commercial & Industrial
# value_sales                                                  38.28
# value_cost                                                 25.4568
# value_quantity                                                12.0
# value_price_adjustment                                           0
# currency                                                       AUD
# invoice_number                                             2185745
# line_number                                                      1
# invoice_date                                              20120216
# customer_order_number                                      2833515
# order_date                                                20120216
#
#                                                                  2  \
# accounting_date                                           20120509
# fiscal_year                                                   2012
# fiscal_month                                                    11
# calendar_year                                                 2012
# calendar_month                                                   5
# company_code                                                   101
# customer_code                                            361000403
# customer_district_code                                         300
# item_code                           GENIE8WWWBC
# business_area_code                  LMP
# item_group_code                     LMP01008
# item_class_code                     LMP01
# item_type                                                        5
# bonus_group_code                                   Trade
# environment_group_code              S
# technology_group_code     SYLV
# commission_group_code               NET_SALES
# reporting_classification                             Discontinuing
# light_source                                           Traditional
# warehouse_code                                                 V0
# abc_class_code                                                   J
# abc_class_volume                                                 J
# business_chain_l1_code                                         BPS
# business_chain_l1_name                       BrightPower Solutions
# contact_method_code                 NA
# salesperson_code                                              P345
# order_type_code                                                NOR
# market_segment                             Commercial & Industrial
# value_sales                                                   40.2
# value_cost                                                 25.4568
# value_quantity                                                12.0
# value_price_adjustment                                           0
# currency                                                       AUD
# invoice_number                                             2217807
# line_number                                                      1
# invoice_date                                              20120509
# customer_order_number                                      2864857
# order_date                                                20120508
#
#                                                                  3  \
# accounting_date                                           20120518
# fiscal_year                                                   2012
# fiscal_month                                                    11
# calendar_year                                                 2012
# calendar_month                                                   5
# company_code                                                   101
# customer_code                                            565540415
# customer_district_code                                         500
# item_code                           GENIE8WWWBC
# business_area_code                  LMP
# item_group_code                     LMP01008
# item_class_code                     LMP01
# item_type                                                        5
# bonus_group_code                                   Trade
# environment_group_code              S
# technology_group_code     SYLV
# commission_group_code               NET_SALES
# reporting_classification                             Discontinuing
# light_source                                           Traditional
# warehouse_code                                                 S0
# abc_class_code                                                   J
# abc_class_volume                                                 J
# business_chain_l1_code                                         GEW
# business_chain_l1_name                 Global Electric Wholesalers
# contact_method_code                 NA
# salesperson_code                                              T504
# order_type_code                                                EDI
# market_segment                             Commercial & Industrial
# value_sales                                                   20.1
# value_cost                                                 12.7284
# value_quantity                                                 6.0
# value_price_adjustment                                           0
# currency                                                       AUD
# invoice_number                                             2222758
# line_number                                                      1
# invoice_date                                              20120518
# customer_order_number                                      2869759
# order_date                                                20120518
#
#                                                                  4  \
# accounting_date                                           20120109
# fiscal_year                                                   2012
# fiscal_month                                                     7
# calendar_year                                                 2012
# calendar_month                                                   1
# company_code                                                   101
# customer_code                                            565540415
# customer_district_code                                         500
# item_code                           GENIE8WWWBC
# business_area_code                  LMP
# item_group_code                     LMP01008
# item_class_code                     LMP01
# item_type                                                        5
# bonus_group_code                                   Trade
# environment_group_code              S
# technology_group_code     SYLV
# commission_group_code               NET_SALES
# reporting_classification                             Discontinuing
# light_source                                           Traditional
# warehouse_code                                                 S0
# abc_class_code                                                   J
# abc_class_volume                                                 J
# business_chain_l1_code                                         GEW
# business_chain_l1_name                 Global Electric Wholesalers
# contact_method_code                 NA
# salesperson_code                                              T504
# order_type_code                                                EDI
# market_segment                             Commercial & Industrial
# value_sales                                                  19.14
# value_cost                                                 12.7284
# value_quantity                                                 6.0
# value_price_adjustment                                           0
# currency                                                       AUD
# invoice_number                                             2170374
# line_number                                                      1
# invoice_date                                              20120109
# customer_order_number                                      2819189
# order_date                                                20120109
#
#                                                                  5  \
# accounting_date                                           20120504
# fiscal_year                                                   2012
# fiscal_month                                                    11
# calendar_year                                                 2012
# calendar_month                                                   5
# company_code                                                   101
# customer_code                                            361000410
# customer_district_code                                         300
# item_code                           GENIE8WWWBC
# business_area_code                  LMP
# item_group_code                     LMP01008
# item_class_code                     LMP01
# item_type                                                        5
# bonus_group_code                                   Trade
# environment_group_code              S
# technology_group_code     SYLV
# commission_group_code               NET_SALES
# reporting_classification                             Discontinuing
# light_source                                           Traditional
# warehouse_code                                                 V0
# abc_class_code                                                   J
# abc_class_volume                                                 J
# business_chain_l1_code                                         BPS
# business_chain_l1_name                       BrightPower Solutions
# contact_method_code                 NA
# salesperson_code                                              P347
# order_type_code                                                NOR
# market_segment                             Commercial & Industrial
# value_sales                                                   20.1
# value_cost                                                 12.7284
# value_quantity                                                 6.0
# value_price_adjustment                                           0
# currency                                                       AUD
# invoice_number                                             2216019
# line_number                                                      2
# invoice_date                                              20120504
# customer_order_number                                      2863367
# order_date                                                20120503
#
#                                                                  6  \
# accounting_date                                           20120626
# fiscal_year                                                   2012
# fiscal_month                                                    12
# calendar_year                                                 2012
# calendar_month                                                   6
# company_code                                                   101
# customer_code                                            361000410
# customer_district_code                                         300
# item_code                           GENIE8WWWBC
# business_area_code                  LMP
# item_group_code                     LMP01008
# item_class_code                     LMP01
# item_type                                                        5
# bonus_group_code                                   Trade
# environment_group_code              S
# technology_group_code     SYLV
# commission_group_code               NET_SALES
# reporting_classification                             Discontinuing
# light_source                                           Traditional
# warehouse_code                                                 V0
# abc_class_code                                                   J
# abc_class_volume                                                 J
# business_chain_l1_code                                         BPS
# business_chain_l1_name                       BrightPower Solutions
# contact_method_code                 NA
# salesperson_code                                              P347
# order_type_code                                                NOR
# market_segment                             Commercial & Industrial
# value_sales                                                   20.1
# value_cost                                                 12.7284
# value_quantity                                                 6.0
# value_price_adjustment                                           0
# currency                                                       AUD
# invoice_number                                             2238742
# line_number                                                      1
# invoice_date                                              20120626
# customer_order_number                                      2885718
# order_date                                                20120626
#
#                                                                  7  \
# accounting_date                                           20120605
# fiscal_year                                                   2012
# fiscal_month                                                    12
# calendar_year                                                 2012
# calendar_month                                                   6
# company_code                                                   101
# customer_code                                            361010426
# customer_district_code                                         300
# item_code                           GENIE8WWWBC
# business_area_code                  LMP
# item_group_code                     LMP01008
# item_class_code                     LMP01
# item_type                                                        5
# bonus_group_code                                   Trade
# environment_group_code              S
# technology_group_code     SYLV
# commission_group_code               NET_SALES
# reporting_classification                             Discontinuing
# light_source                                           Traditional
# warehouse_code                                                 V0
# abc_class_code                                                   J
# abc_class_volume                                                 J
# business_chain_l1_code                                         BPS
# business_chain_l1_name                       BrightPower Solutions
# contact_method_code                 NA
# salesperson_code                                              P347
# order_type_code                                                NOR
# market_segment                             Commercial & Industrial
# value_sales                                                   20.1
# value_cost                                                 12.7284
# value_quantity                                                 6.0
# value_price_adjustment                                           0
# currency                                                       AUD
# invoice_number                                             2230005
# line_number                                                      1
# invoice_date                                              20120605
# customer_order_number                                      2877158
# order_date                                                20120605
#
#                                                                  8  \
# accounting_date                                           20120622
# fiscal_year                                                   2012
# fiscal_month                                                    12
# calendar_year                                                 2012
# calendar_month                                                   6
# company_code                                                   101
# customer_code                                            361010426
# customer_district_code                                         300
# item_code                           GENIE8WWWBC
# business_area_code                  LMP
# item_group_code                     LMP01008
# item_class_code                     LMP01
# item_type                                                        5
# bonus_group_code                                   Trade
# environment_group_code              S
# technology_group_code     SYLV
# commission_group_code               NET_SALES
# reporting_classification                             Discontinuing
# light_source                                           Traditional
# warehouse_code                                                 V0
# abc_class_code                                                   J
# abc_class_volume                                                 J
# business_chain_l1_code                                         BPS
# business_chain_l1_name                       BrightPower Solutions
# contact_method_code                 NA
# salesperson_code                                              P347
# order_type_code                                                NOR
# market_segment                             Commercial & Industrial
# value_sales                                                   80.4
# value_cost                                                 50.9136
# value_quantity                                                24.0
# value_price_adjustment                                           0
# currency                                                       AUD
# invoice_number                                             2237500
# line_number                                                      1
# invoice_date                                              20120622
# customer_order_number                                      2884561
# order_date                                                20120622
#
#                                                                  9
# accounting_date                                           20120403
# fiscal_year                                                   2012
# fiscal_month                                                    10
# calendar_year                                                 2012
# calendar_month                                                   4
# company_code                                                   101
# customer_code                                            361001440
# customer_district_code                                         300
# item_code                           GENIE11WWWES
# business_area_code                  LMP
# item_group_code                     LMP01008
# item_class_code                     LMP01
# item_type                                                        5
# bonus_group_code                                   Trade
# environment_group_code              S
# technology_group_code     SYLV
# commission_group_code               NET_SALES
# reporting_classification                             Discontinuing
# light_source                                           Traditional
# warehouse_code                                                 V0
# abc_class_code                                                   J
# abc_class_volume                                                 J
# business_chain_l1_code                                         BPS
# business_chain_l1_name                       BrightPower Solutions
# contact_method_code                 NA
# salesperson_code                                              P342
# order_type_code                                                NOR
# market_segment                             Commercial & Industrial
# value_sales                                                   40.2
# value_cost                                                 25.4568
# value_quantity                                                12.0
# value_price_adjustment                                           0
# currency                                                       AUD
# invoice_number                                             2204541
# line_number                                                      1
# invoice_date                                              20120403
# customer_order_number                                      2851981
# order_date                                                20120403

# %% [markdown]
# ##### *G) Technology Group Codes*

# %%
# Display unique values in this column

print(data["technology_group_code"].unique())
print("--" * 30)

# Calculate total unique values in the feature

print(f"There are {data['technology_group_code'].nunique()} unique values in Technology Group Codes")
# Out:
# ['SYLV                                    '
#  'NA                                      '
#  'PIER                                    ' '96' '219' '92' '214' '380'
#  '102' '123' '110' '98' '213' '580' '108' '999' '198'
#  'SCHR                                    ' '82' '140' '540'
#  'AUST                                    ' '480' '760' '460' '600' '520'
#  '998' '570' '280' '330' '220' '415' '340' '225'
#  'CSE                                     ' '565' '410' '560' '800' '680'
#  '320' '550' '400' '160' '440' '420' '500' '555' '360' '290' '780' '545'
#  '181' '240' '640' '820' '595' '300' '830' '70' '850' '86' '720' '740'
#  '310' 'FGDFT                                   ' '350' '206' '64'
#  'PNZ                                     ' '63'
#  'CROM                                    ' '100' '78' '207' '208' '76'
#  '211' '205' '85' '90' '68' '130'
#  'GLG                                     '
#  'INLIT                                   ' '72' '61' '880' '217' '215'
#  '80' '210' 'INZ                                     ' '250' '118' '66'
#  'PHANT                                   '
#  'DIGIN                                   ' '114' '112' '128' '88']
# ------------------------------------------------------------
# There are 103 unique values in Technology Group Codes

# %%
# Create a list containing unexpected Technology Group codes

undocumented_code = ["PHANT", "DIGIN", "114", "112", "128", "88"]

# Check total rows presented in each of the unexpected Technology Group codes in the dataset
for i in undocumented_code:
    print(i)
    print(f" There are {data[data['technology_group_code'] == i].shape[0]} values")
    print("-" * 20)
# Out:
# PHANT
#  There are 0 values
# --------------------
# DIGIN
#  There are 0 values
# --------------------
# 114
#  There are 1 values
# --------------------
# 112
#  There are 1 values
# --------------------
# 128
#  There are 185 values
# --------------------
# 88
#  There are 2 values
# --------------------

# %%
# Drop the rows presented in each of the unexpected Technology Group codes in the dataset

data = data.drop(data[data["technology_group_code"].isin(undocumented_code)].index)

# %%
data.shape
# Out:
# (1979107, 38)

# %% [markdown]
# ### **D. Handling Inconsistencies (Categorical and Date Value)**

# %% [markdown]
# #### I. Conversion of Data Types

# %%
# Convert integer dates to datetime format

data["accounting_date"] = pd.to_datetime(data["accounting_date"], format="%Y%m%d")
data["invoice_date"] = pd.to_datetime(data["invoice_date"], format="%Y%m%d")
data["order_date"] = pd.to_datetime(data["order_date"], format="%Y%m%d")

# %%
data.head()
# Out:
#   accounting_date  fiscal_year  fiscal_month  calendar_year  calendar_month  \
# 0      2012-05-09         2012            11           2012               5
# 1      2012-02-16         2012             8           2012               2
# 2      2012-05-09         2012            11           2012               5
# 3      2012-05-18         2012            11           2012               5
# 4      2012-01-09         2012             7           2012               1
#
#    company_code customer_code  customer_district_code  \
# 0           101     411800601                     410
# 1           101     361000403                     300
# 2           101     361000403                     300
# 3           101     565540415                     500
# 4           101     565540415                     500
#
#                         item_code              business_area_code  ...  \
# 0  GENIE8WWWBC                     LMP                             ...
# 1  GENIE8WWWBC                     LMP                             ...
# 2  GENIE8WWWBC                     LMP                             ...
# 3  GENIE8WWWBC                     LMP                             ...
# 4  GENIE8WWWBC                     LMP                             ...
#
#   value_sales value_cost  value_quantity value_price_adjustment currency  \
# 0      218.40   178.1976            84.0                      0      AUD
# 1       38.28    25.4568            12.0                      0      AUD
# 2       40.20    25.4568            12.0                      0      AUD
# 3       20.10    12.7284             6.0                      0      AUD
# 4       19.14    12.7284             6.0                      0      AUD
#
#   invoice_number line_number invoice_date customer_order_number order_date
# 0        2217887           1   2012-05-09               2865354 2012-05-09
# 1        2185745           1   2012-02-16               2833515 2012-02-16
# 2        2217807           1   2012-05-09               2864857 2012-05-08
# 3        2222758           1   2012-05-18               2869759 2012-05-18
# 4        2170374           1   2012-01-09               2819189 2012-01-09
#
# [5 rows x 38 columns]

# %% [markdown]
# #### II. Conversions of data in "customer_code" to String & Removal of Leading/Trailing Spaces

# %% [markdown]
# Based on overview of unique values, entries in customer_code seem to contain 2 different types of data including String and Integer. Hence, converting the data to string is necessary to ensure consistency for subsequent reference in further analyses.

# %%
data["customer_code"] = data["customer_code"].astype(str).str.strip()

# %%
# Identify columns that are either objects (strings) or mixed types
string = data.select_dtypes(include=['object']).columns

# List of specific columns you know should be strings and may have leading/trailing spaces
columns = ["item_code", "business_area_code", "item_group_code", 
                    "item_class_code", "bonus_group_code", "environment_group_code", 
                    "technology_group_code", "commission_group_code", "business_chain_l1_code", 
                    "contact_method_code"]

# Apply stripping only to string columns that may have leading/trailing spaces
for col in columns:
    if col in string:
        data[col] = data[col].str.strip()

# %%
# Re-Check unique values and their formats in each feature

for col in data.columns:
    uniques = data[col].unique()
    print(col)
    print(uniques)
    print("-" * 50)
# Out:
# accounting_date
# <DatetimeArray>
# ['2012-05-09 00:00:00', '2012-02-16 00:00:00', '2012-05-18 00:00:00',
#  '2012-01-09 00:00:00', '2012-05-04 00:00:00', '2012-06-26 00:00:00',
#  '2012-06-05 00:00:00', '2012-06-22 00:00:00', '2012-04-03 00:00:00',
#  '2012-04-18 00:00:00',
#  ...
#  '2013-12-31 00:00:00', '2013-12-24 00:00:00', '2013-12-27 00:00:00',
#  '2013-12-23 00:00:00', '2013-12-30 00:00:00', '2013-12-22 00:00:00',
#  '2013-11-23 00:00:00', '2013-11-16 00:00:00', '2013-07-27 00:00:00',
#  '2013-08-31 00:00:00']
# Length: 543, dtype: datetime64[ns]
# --------------------------------------------------
# fiscal_year
# [2012 2013 2014]
# --------------------------------------------------
# fiscal_month
# [11  8  7 12 10  9  3  5  6  1  2  4]
# --------------------------------------------------
# calendar_year
# [2012 2013]
# --------------------------------------------------
# calendar_month
# [ 5  2  1  6  4  3  9 11 12  7  8 10]
# --------------------------------------------------
# company_code
# [101 100 140 205 170 220 950 240 510 120]
# --------------------------------------------------
# customer_code
# ['411800601' '361000403' '565540415' ... 'ZI8005601' 'ZI2000017'
#  'Z85020601']
# --------------------------------------------------
# customer_district_code
# [410 300 500 310 400 200 210 720 710 600 510 530 535 540 520 545]
# --------------------------------------------------
# item_code
# ['GENIE8WWWBC' 'GENIE11WWWES' 'GENIE18WCDLES' ... 'DT3132221822ADW'
#  'DT34675139E' '0.90811.00-910']
# --------------------------------------------------
# business_area_code
# ['LMP' 'FLD' 'OTH' 'SUR' 'COM' 'DLT' 'TRO' 'URB' 'HLB' 'SAE' 'RWY' 'LCP'
#  'PEN' 'EXL' 'TAL' '945' '950' '980' '920' '960' '910' '930' '999' '970'
#  '940' '985' 'IAE' 'IAI']
# --------------------------------------------------
# item_group_code
# ['LMP01008' 'FLD03002' '999' 'SUR08001' 'FLD02002' 'COM90001' 'DLT01002'
#  'TRO03001' 'COM99001' 'SUR80001' 'URB04002' 'FLD90001' 'SUR09001'
#  'COM08001' 'HLB02002' 'URB04001' 'SAE02001' 'TRO02001' 'SUR01001'
#  'RWY01001' 'COM07001' 'COM12001' 'LCP02001' 'LMP04002' 'SAE90001'
#  'SUR04001' 'TRO90001' 'TRO02002' 'TRO02004' 'SAE80001' 'FLD01002'
#  'SAE01001' 'SAE02002' 'SUR99001' 'SUR90001' 'TRO80001' 'TRO03004'
#  'SAE01002' 'HLB02001' 'DLT04002' 'DLT02002' 'PEN01003' 'COM10001'
#  'URB03001' 'LMP01001' 'EXL01001' 'DLT90001' 'COM06001' 'COM16001'
#  'URB02001' 'URB90001' 'SUR05001' 'TRO99001' 'TRO01001' 'COM19001'
#  'TRO03002' 'SUR07002' 'RWY90001' 'FLD02004' 'HLB01001' 'RWY02001'
#  'FLD99001' 'SUR07001' 'COM01001' 'TAL05001' 'HLB01003' 'LMP06001'
#  'SUR03001' 'TRO03003' 'HLB90001' 'TRO02003' 'EXL06001' 'SUR07003'
#  'EXL90001' 'COM14001' 'SUR06002' 'COM09001' 'TAL90001' 'COM05001'
#  'LMP03002' 'COM03002' 'COM17001' 'SUR06001' 'RWY99001' 'LCP01004'
#  'COM03003' 'COM03001' 'COM15001' 'FLD01004' 'LMP06002' 'LMP03013'
#  'LMP04010' 'LMP01009' '250105' '251310' 'PEN01004' 'PEN01002' 'LMP10005'
#  'LMP10004' 'LMP10016' 'LCP90001' '17010' '250125' '250135' 'LCP01002'
#  '17020' 'RWY01002' 'LF100000' 'RWY02002' '17050' 'TAL02002' 'FASTRA00'
#  'NUALIG00' 'FGALAX00' 'TAL06001' '17070' 'LP900000' 'FFLUSH00' 'SA2MAX00'
#  'NSTCKPLE' 'TAL01008' 'CSECON00' 'GHIDIN00' 'PEN09001' 'FBULLS00'
#  'FLD03004' 'CSELIG00' 'TAL06004' 'FSYLEC00' 'RPIXEL00' 'LCP99001'
#  'TAL02004' 'PEN10001' 'TAL06005' 'NSTCKFIX' 'LMP90001' 'LMP04018'
#  'NSTCKCCD' 'OTHER71' 'CEQUIL00' 'FSLIML00' 'FLD02001' 'CSLIMD00'
#  'LPUNTO00' 'CSIGNO00' 'LL100000' 'LL300000' 'CSEEXWN0' 'PEN90002'
#  'LMP10007' 'LMP06009' 'CLED150T' 'TAL02003' 'CSEFFL00' 'LMP10011'
#  'CSEGLA00' 'RROADS00' 'LC500000' 'SS1MIN00' 'LMP05029' 'LMP10020'
#  'LMP10021' 'CMOTIF00' 'TAL04005' 'CINSTA00' 'LMP10023' 'RWY04001'
#  'TAL01004' 'LB500000' 'TAL04003' 'COV65000' 'SMODAR00' 'OTHER91'
#  'CLED100T' 'TAL01009' 'CLYTE300' 'LMP06007' 'CEQUI400' 'TAL01007'
#  'CTORUS00' 'CSTDEV00' 'CTEQSP00' 'LC230000' 'LA300000' 'TAL01002'
#  'LMP07004' 'COFFLY00' 'RTUNPS00' 'CSTPRO00' 'FPIRAN00' 'LMP05030'
#  'LA100000' 'CMYRIA00' 'LA900000' 'LMP04015' 'LG370000' 'LMP10024'
#  'FRAWMA00' 'LD250000' 'IAI10001' 'LMP10003' 'LL400000' 'LMP12001'
#  'LG150000' 'LS010000' 'CSTERL00' 'CSKYLI00' 'CMONIT00' 'CINSA175'
#  'LD320000' 'CGIOTT00' 'TAL02005' 'CINPACT0' 'CINSE120' 'CAXOXL00'
#  'CGIRO000' 'LG420000' 'CCASSI00' 'FSYCAP00' 'CPIXO000' 'TAL01010'
#  'COPALI00' 'LD490000' 'SQUADT00' 'CINSA225' 'SNOVAL00' 'CGI33500'
#  'LK010000' 'CINSAR00' 'CINST900' 'CINST700' 'CBEACO00' 'CSIGN155'
#  'LC210000' 'LC410000' 'LC100000' 'LG900000' 'FPOLES00' 'LMP10013'
#  'LG380000' 'CDECAP00' '240' 'N85' '416' 'N59' 'N75' '418' '243' '723'
#  'N51' '431' 'FLRSTK' '239' '510' '17040' 'TAL01005' 'LMP10018' 'PEN03001'
#  '180' 'FLD01003' '355' '16626' '209' '44' '421' '725' '359' 'FLD01001'
#  'DLT04004' '120' '995' 'CMOT8200' 'CINSTAR8' 'CINSE100' 'CBRIO000'
#  'DLT03001' 'FCUBAN00' 'CFOLIO00' 'FTRITO00' 'CEQIN300' 'LA350000'
#  'CLYTES00' 'LL500000' 'SCITYL00' 'CCIELO00' 'SR1MIN00' 'TAL07002'
#  'OTHER75' 'CINSA150' 'FILIA000' '193' 'IAI09001' '251305' '16312'
#  'PEN04003' '20' 'CSEEB000' '250520' 'HLB01002' 'LC010000' '251525'
#  'FLINEA00' 'CSEEXDN0' 'LMP09002' 'CSIGN115' 'OTHER92' '231' 'LMP08001'
#  'CACCES00' 'LG100000' 'SA1MIN00' 'LMP10017' 'LMP10022' 'P12197' '11021'
#  'LCP01003' '6000' 'RWY03002' 'HLB80001' 'EXL03001' 'CSEFC000' 'CEXFNII0'
#  'NSTCKOTH' 'RWY05001' 'RSOLAR00' 'LL600000' 'RRAWMA00' 'SA2MIN00'
#  'CINST800' 'CSEARMA0' 'CPENTO00' 'LCP02002' 'TAL04002' 'SSM30000'
#  'DLT01004' 'FSUPER00' 'OTHER76' 'CROTOS00' 'FBLINE00' '250140' '670'
#  'IAI05001' 'P12044' 'TAL02006' 'SEL' 'CSECSDE0' 'FGTRAY00' 'CSETBE40'
#  'CFJB3A00' 'CFJB2A00' 'NSTCKLMP' '16124' 'CFJB0A00' 'PEN99001' 'IAI08001'
#  'LMP10009' 'CDLREC00' 'PEN03003' 'FCOURT00' 'FLD03001' '980' 'SCLSPO00'
#  'FBENEL00' 'FRAVEN0L' 'IAI11001']
# --------------------------------------------------
# item_class_code
# ['LMP01' 'FLD03' '14001' 'SUR08' 'FLD02' 'COM90' 'DLT01' 'TRO03' 'COM99'
#  'SUR80' 'URB04' 'FLD90' 'SUR09' 'COM08' 'HLB02' 'SAE02' 'TRO02' 'SUR01'
#  'RWY01' 'COM07' 'COM12' 'LCP02' 'LMP04' 'SAE90' 'SUR04' 'TRO90' 'SAE80'
#  'FLD01' 'SAE01' 'SUR99' 'SUR90' 'TRO80' 'DLT04' 'DLT02' 'PEN01' 'COM10'
#  'URB03' 'EXL01' 'DLT90' 'COM06' 'COM16' 'URB02' 'URB90' 'SUR05' 'TRO99'
#  'TRO01' 'COM19' 'SUR07' 'RWY90' 'HLB01' 'RWY02' 'FLD99' 'COM01' 'TAL05'
#  'LMP06' 'SUR03' 'HLB90' 'EXL06' 'EXL90' 'COM14' 'SUR06' 'COM09' 'TAL90'
#  'COM05' 'LMP03' 'COM03' 'COM17' 'RWY99' 'LCP01' 'COM15' 'RWY03' 'DLT99'
#  'LMP99' 'COM13' 'EXL99' 'COM04' 'COM18' 'HLB99' 'TAL04' 'SAE99' 'COM80'
#  'LMP09' 'URB99' 'COM02' '4005' 'SUR02' 'RWY06' '4003' '2004' 'LMP10'
#  'COM11' 'LMP11' '2013' '2599' '1001' 'LMP07' '5002' '1002' '2003' '8001'
#  '2001' '2005' '5003' 'URB01' 'URB05' '6001' '2502' '2011' 'LMP02' '2002'
#  'LMP05' '3002' 'COM70' '1999' 'DLT05' 'PEN90' '4004' '2016' '2505' '4002'
#  '6002' '16135' '2503' '3005' 'FLD04' '2008' '5004' '2604' 'EXL02' '5005'
#  'DLT03' 'TAL07' 'TAL99' 'EXL05' '16131' '17100' 'SUR10' '2501' '16133'
#  'TAL01' 'TAL02' '16137' 'TAL08' '2512' '2516' 'SUR12' 'SUR11' '2515'
#  'SUR13' '2514' 'SUR14' '2508' 'IAE05' '2507' 'PEN04' '2511' 'PEN08'
#  '2509' '2504' '2510' '2517' '17200' '16121' '2513' 'LCP90' '3006' '2012'
#  'TAL06' '15999' '11103' 'PEN09' '17300' 'LCP99' 'PEN10' 'LMP90' '4599'
#  '2603' '2006' '4009' '16134' '6003' 'RWY04' '16132' 'IAI10' 'LMP12'
#  '16138' '4504' '2605' '2607' '4502' '4016' 'PEN03' '2007' '3999' '17001'
#  'IAI09' 'LMP08' 'HLB80' 'EXL03' 'RWY05' 'IAI05' 'PEN99' 'IAI08' 'IAI11']
# --------------------------------------------------
# item_type
# [5 1 7 8 6 4 2 9 3]
# --------------------------------------------------
# bonus_group_code
# ['Trade' 'Professional']
# --------------------------------------------------
# environment_group_code
# ['S' 'P' 'D' 'Z' 'C' 'M' 'R' 'I' 'NA']
# --------------------------------------------------
# technology_group_code
# ['SYLV' 'NA' 'PIER' '96' '219' '92' '214' '380' '102' '123' '110' '98'
#  '213' '580' '108' '999' '198' 'SCHR' '82' '140' '540' 'AUST' '480' '760'
#  '460' '600' '520' '998' '570' '280' '330' '220' '415' '340' '225' 'CSE'
#  '565' '410' '560' '800' '680' '320' '550' '400' '160' '440' '420' '500'
#  '555' '360' '290' '780' '545' '181' '240' '640' '820' '595' '300' '830'
#  '70' '850' '86' '720' '740' '310' 'FGDFT' '350' '206' '64' 'PNZ' '63'
#  'CROM' '100' '78' '207' '208' '76' '211' '205' '85' '90' '68' '130' 'GLG'
#  'INLIT' '72' '61' '880' '217' '215' '80' '210' 'INZ' '250' '118' '66'
#  'PHANT' 'DIGIN']
# --------------------------------------------------
# commission_group_code
# ['NET_SALES' 'REBATE_EXEMPT_EOL' 'REBATE_EXEMPT_TP']
# --------------------------------------------------
# reporting_classification
# ['Discontinuing' 'Continuing']
# --------------------------------------------------
# light_source
# ['Traditional' 'LED' 'Accessories']
# --------------------------------------------------
# warehouse_code
# ['Q1 ' 'V0 ' 'S0 ' 'T0 ' 'Q0 ' 'N0 ' 'KN0' 'W0 ' 'S1 ' 'Unk' 'GS0' 'GN0'
#  'CN0' 'CQ0' 'CV0' 'GW0' 'CS0' 'CW0' 'GQ0' 'AS0' 'CT0' 'CS1' 'CN1' 'CZ0'
#  'LW0' 'LQ0' 'LS1' 'LV0' 'LN9' 'LS0' 'FWE' 'EN0' 'FW2' 'JT0' 'FA1' 'FWA'
#  'FA2' '1N0' '1S0' '5N2' '5V0' '5S0' '5W0' '1V0' '1Q0' '1N1' '1W0' '1Q1'
#  '5Q0' '5T0' '5S1' '5N1' '1T0' '1S1' '5Q1' '1T1']
# --------------------------------------------------
# abc_class_code
# ['J' 'B' 'D' 'E' 'C' 'I' 'A' 'F' 'U' 'G']
# --------------------------------------------------
# abc_class_volume
# ['J' 'U' 'D' 'I' 'C' 'E' 'G' 'B' 'A' 'H']
# --------------------------------------------------
# business_chain_l1_code
# ['ELC' 'BPS' 'GEW' 'MED' 'AEG' 'UES' 'INTERCO' 'PTD' 'NLG' 'ZZZ' 'NES'
#  'ZZ2' 'ZZ7' 'ZZ8' 'ZZ1' 'ZZ3' 'ZZ6' 'CET' 'ZZ9' 'ZZ5' 'REP' 'Z4500'
#  'Z2000' 'Z4000' 'Z4100' 'Z3200' 'Z7500' 'Z8500' 'ZA900' 'ZI800' 'ZI900'
#  'Z6100' 'ZI3000' 'ZI4500' 'ZI4000' 'ZI2000' 'Z8100' 'Z2500' 'Z3500'
#  'Z6500' 'Z850339' 'Z6800' 'Z850358' 'ZI3500' 'ZA800' 'Z9000' 'ZA200'
#  'ZI80084']
# --------------------------------------------------
# business_chain_l1_name
# ['ElectraCorp Ltd' 'BrightPower Solutions' 'Global Electric Wholesalers'
#  'Metro Electrical Distributors' 'Aussie Energy Group'
#  'Unified Electrical Suppliers' 'InterGlobal Trading' 'PowerTools Direct'
#  'Nationwide Lighting Group' 'General Suppliers Pty'
#  'NextGen Electrical Solutions' 'Independent Retailers Association'
#  'UtilityWorks Group' 'EndUser Solutions' 'Builders Supply Network'
#  'ProLighting Specialists' 'Constructor Supplies' 'CetraPro Distributors'
#  'Corporate Builders Consortium' 'SalesPro Accounts'
#  'PowerHub Distribution' 'Ideal Electrical Solutions'
#  'Russell & Partners Electric' 'Stewart Electrical Wholesalers'
#  'CraneCo Distribution' 'DIY Supplies Network' 'Independent Traders Ltd'
#  'HeadOffice Electrical Group' 'Inlite Solutions' 'Inlite NZ Ltd'
#  'Beacon Lighting Supplies' 'CraneCo Old Branch'
#  'Russell & Radcliffe Electric' 'Corporate HQ Solutions'
#  'NextGen Electrical Group' 'Corys Energy Systems' 'MitrePro Suppliers'
#  'Active Electric Solutions' 'ITM Solutions Group' 'Electical Vista'
#  'Independent' 'Export' 'Electrical Active Supply']
# --------------------------------------------------
# contact_method_code
# ['NA' 'FAX' 'NIM' ... 'SPT' 'S' 'SZA']
# --------------------------------------------------
# salesperson_code
# ['T612' 'P345' 'T504' 'P347' 'P342' 'P344' 'T408' 'P237' 'T203' 'T204'
#  'P248' 'T215' 'P415' 'P218' 'P350' 'T432' 'R806' 'T200' 'T220' 'T431'
#  'T428' 'P515' 'P107' 'T607' 'T312' 'T400' 'T207' 'T418' 'T300' 'T405'
#  'T206' 'T302' 'P506' 'P326' 'T602' 'T603' 'T606' 'P600' 'P399' 'T304'
#  'R327' 'P421' 'P500' 'T217' 'T111' 'T306' 'P327' 'P225' 'P213' 'P427'
#  'T503' 'T510' 'P300' 'P513' 'T303' 'T205' 'R520' 'T404' 'P200' 'T318'
#  'P601' 'T508' 'P205' 'P331' 'P602' 'P245' 'T505' 'T501' 'P306' 'T227'
#  'T414' 'T500' 'P202' 'T407' 'T228' 'T406' 'P419' 'P400' 'T214' 'R266'
#  'R620' 'T413' 'T600' 'P227' 'P310' 'P404' 'R338' 'R635' 'T310' 'T314'
#  'R622' 'P208' 'P134' 'P236' 'R300' 'P230' 'T225' 'T222' 'P304' 'T502'
#  'T305' 'T401' 'T319' 'T308' 'R274' 'T513' 'R232' 'P246' 'T209' 'P516'
#  'T415' 'P611' 'P412' 'T231' 'P504' 'P224' 'P211' 'T604' 'T229' 'P221'
#  'P303' 'T403' 'P127' 'P214' 'P430' 'P417' 'T226' 'R436' 'T420' 'P239'
#  'RM34' 'RM21' 'RM89' 'RM73' 'RM47' 'RM44' 'RM79' 'RM92' 'RM84' 'RM20'
#  'RM93' 'RM82' 'RM11' 'RM22' 'RM96' 'RM76' 'RM98' 'RM87' 'RM18' 'RM15'
#  'T411' 'RM91' 'RM99' 'T224' 'RM88' 'RM77' 'RM58' 'RM05' 'RM01' 'RM62'
#  'RM90' 'RM94' 'T906' 'T909' 'RC12' 'RSP1' 'T230' 'T316' 'RM55' 'T211'
#  'RM02' 'T210' 'RSP2' 'P121' 'T317' 'T218' 'T506' 'T208' 'T221' 'RC17'
#  'P428' 'T410' 'R727' 'RC22' 'P599' 'T512' 'RB03' 'R605' 'R400' 'R500'
#  'R220' 'RZ81' 'RZ22' 'RZ99' 'RE04' 'RZ85' 'RZ84' 'RZ65' 'RZ24' 'RZ52'
#  'R999' 'RZ82' 'RB05' 'RZ70' 'RZ63' 'RZ83' 'RZ61' 'RZ02' 'RZ71' 'IN06'
#  'IN03' 'IN02' 'RZ62' 'IN04' 'RZ98' 'IN07' 'IN01' 'RZ54' 'IN05' 'RZ64'
#  'RM04' 'RE06' 'RE01' 'RZ72' 'P316' 'P335' 'R987' 'RV01' 'P507' 'RZ76'
#  'P423' 'IN10' 'P338' 'P207' 'P219' 'P605' 'P206' 'P503' 'P341' 'P349'
#  'P426' 'IN09' 'P315' 'T213' 'P510' 'P235' 'P943' 'I375' 'R441' 'R640'
#  'P223' 'P312' 'P606' 'RZ38' 'P346' 'RZ97' 'DG06' 'P348' 'R625' 'RA01'
#  'R260' 'RZ28' 'RZ04' 'RE08' 'RZ05' 'R449' 'P609' 'RT18']
# --------------------------------------------------
# order_type_code
# ['NOR' 'EDI' 'CDG' 'PRO' 'NOS' 'CRR' 'EXP' 'EDS' 'CSH' 'PRD' 'CRD' 'NOH'
#  'COP' 'OBS' 'MIN' 'COA' 'PSA' 'PPD' 'WDC' 'PMO' 'CPR' 'CRP' 'PM0' 'PGS'
#  'SPL' 'AES' 'ZCG' 'ZCR' 'SPC' 'ZOP' 'ZC2' '5TN' 'PUP' 'PPO' 'ZD3' 'CSO']
# --------------------------------------------------
# market_segment
# ['Commercial & Industrial']
# --------------------------------------------------
# value_sales
# [218.4   38.28  40.2  ... 150.67 425.9  232.19]
# --------------------------------------------------
# value_cost
# [178.1976  25.4568  12.7284 ...  96.8759 681.45    58.7915]
# --------------------------------------------------
# value_quantity
# [  84.   12.    6. ... 2389. -188. 1664.]
# --------------------------------------------------
# value_price_adjustment
# [0 1]
# --------------------------------------------------
# currency
# ['AUD' 'USD' 'AUS' 'NZD' '   ' 'EUR']
# --------------------------------------------------
# invoice_number
# [2217887 2185745 2217807 ... 2423962 2423898 2383667]
# --------------------------------------------------
# line_number
# [  1   2   3  -2  -3  -7  -6   9  -1 -11 -20   4  -5 -16  -8  -4 -17 -13
#  -12  -9 -18 -10   5   7 -19 -21 -22 -14 -15 -24   6 -23 -26   0 -28 -27
#  -33 -32 -29 -30 -31 -25 -40 -35 -36 -34 -37 -38 -39  14  12   8  11 -56
#   13  10 -47 -48 -49 -50 -41 -66 -67 -68 -61 -62 -63 -64 -65 -69 -70 -51
#  -52 -53 -54 -57 -58 -59 -60 -71 -72 -73 -74 -75 -76 -77 -78 -79 -80 -81
#  -82 -83 -84 -42 -43 -44 -45 -46 -85 -86 -87 -88 -89 -90 -91 -92  16  15
#  -55  21  22  23  24  29  17  28  25  26  27  20  19  18  31  32  30  33
#   34  46  43  45  40  42  35  44  36  41  38  37  39  48  47  49]
# --------------------------------------------------
# invoice_date
# <DatetimeArray>
# ['2012-05-09 00:00:00', '2012-02-16 00:00:00', '2012-05-18 00:00:00',
#  '2012-01-09 00:00:00', '2012-05-04 00:00:00', '2012-06-26 00:00:00',
#  '2012-06-05 00:00:00', '2012-06-22 00:00:00', '2012-04-03 00:00:00',
#  '2012-04-18 00:00:00',
#  ...
#  '2013-12-31 00:00:00', '2013-12-24 00:00:00', '2013-12-27 00:00:00',
#  '2013-12-23 00:00:00', '2013-12-30 00:00:00', '2013-12-22 00:00:00',
#  '2013-11-23 00:00:00', '2013-11-16 00:00:00', '2013-07-27 00:00:00',
#  '2013-08-31 00:00:00']
# Length: 543, dtype: datetime64[ns]
# --------------------------------------------------
# customer_order_number
# [2865354 2833515 2864857 ... 3079457 3079784 3024473]
# --------------------------------------------------
# order_date
# <DatetimeArray>
# ['2012-05-09 00:00:00', '2012-02-16 00:00:00', '2012-05-08 00:00:00',
#  '2012-05-18 00:00:00', '2012-01-09 00:00:00', '2012-05-03 00:00:00',
#  '2012-06-26 00:00:00', '2012-06-05 00:00:00', '2012-06-22 00:00:00',
#  '2012-04-03 00:00:00',
#  ...
#  '2013-09-22 00:00:00', '2013-10-12 00:00:00', '2013-07-13 00:00:00',
#  '2013-07-20 00:00:00', '2013-09-08 00:00:00', '2013-07-06 00:00:00',
#  '2009-03-26 00:00:00', '2013-11-17 00:00:00', '2013-08-24 00:00:00',
#  '2013-12-22 00:00:00']
# Length: 804, dtype: datetime64[ns]
# --------------------------------------------------
# customer_order_number
# [2865354 2833515 2864857 ... 3079457 3079784 3024473]
# --------------------------------------------------
# order_date
# ['2012-05-09T00:00:00.000000000' '2012-02-16T00:00:00.000000000'
#  '2012-05-08T00:00:00.000000000' '2012-05-18T00:00:00.000000000'
#  '2012-01-09T00:00:00.000000000' '2012-05-03T00:00:00.000000000'
#  '2012-06-26T00:00:00.000000000' '2012-06-05T00:00:00.000000000'
#  '2012-06-22T00:00:00.000000000' '2012-04-03T00:00:00.000000000'
#  '2012-04-18T00:00:00.000000000' '2012-01-11T00:00:00.000000000'
#  '2012-01-17T00:00:00.000000000' '2012-03-29T00:00:00.000000000'
#  '2012-04-23T00:00:00.000000000' '2012-01-25T00:00:00.000000000'
#  '2013-08-24T00:00:00.000000000' '2013-12-22T00:00:00.000000000']
# --------------------------------------------------

# %% [markdown]
# #### III. Standardise Categorical Columns

# %% [markdown]
# Check categorical columns such as customer_code, item_code, market_segment, etc., are standardised (e.g., no extra spaces or inconsistent values)

# %%
# Replace incorrect values
data["currency"] = data["currency"].str.strip().replace({"AUS": "AUD"})

print(data["currency"].value_counts())
# Out:
# currency
# AUD    1861774
# NZD     116153
# USD        675
# EUR        503
#              2
# Name: count, dtype: int64

# %%
# Drop 2 rows with empty currency value

data = data.drop(data[data["currency"] == ""].index)

# %% [markdown]
# #### IV. Logical Inconsistencies

# %% [markdown]
# **Order date should be before the invoice date**

# %%
# Ensure invoice_date is after order_date
invalid_dates = data[data['invoice_date'] < data['order_date']]

print(invalid_dates.shape[0])
# Out:
# 22

# %% [markdown]
# There are 22 rows where invoice dates are before their corresponding order dates. Practically, this is not the case in business and the resulting rows should be removed.

# %%
# Drop rows where invoice_date is less than order_date
data.drop(data[data['invoice_date'] < data['order_date']].index, inplace=True)

# Verify the result
print(f"Rows after dropping: {len(data)}")
# Out:
# Rows after dropping: 1979083

# %% [markdown]
# Note

# %% [markdown]
# **Insights for Strategic Focus on Order Types**
# * These are operational codes that classify the type of order transaction, not specific products.
# * The codes help identify normal orders, project orders, returns, price adjustments, and other operational types, helping the company track and manage different kinds of customer transactions.
# * “Do Not Use” codes likely represent outdated or special cases, and should be excluded or flagged for review in data analysis, unless they are still contributing significantly to revenue.
#
# **Suggested Actions**
# * Focus on high-volume order types like NOR, EDI, PRO, and EXP to drive marketing and sales strategies.
# * Review the impact of “Do Not Use” codes to ensure they aren't inadvertently affecting current business operations.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1979083 entries, 0 to 1988381
# Data columns (total 38 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   accounting_date           datetime64[ns]
#  1   fiscal_year               int64
#  2   fiscal_month              int64
#  3   calendar_year             int64
#  4   calendar_month            int64
#  5   company_code              int64
#  6   customer_code             object
#  7   customer_district_code    int64
#  8   item_code                 object
#  9   business_area_code        object
#  10  item_group_code           object
#  11  item_class_code           object
#  12  item_type                 int64
#  13  bonus_group_code          object
#  14  environment_group_code    object
#  15  technology_group_code     object
#  16  commission_group_code     object
#  17  reporting_classification  object
#  18  light_source              object
#  19  warehouse_code            object
#  20  abc_class_code            object
#  21  abc_class_volume          object
#  22  business_chain_l1_code    object
#  23  business_chain_l1_name    object
#  24  contact_method_code       object
#  25  salesperson_code          object
#  26  order_type_code           object
#  27  market_segment            object
#  28  value_sales               float64
#  29  value_cost                float64
#  30  value_quantity            float64
#  31  value_price_adjustment    int64
#  32  currency                  object
#  33  invoice_number            int64
#  34  line_number               int64
#  35  invoice_date              datetime64[ns]
#  36  customer_order_number     object
#  37  order_date                datetime64[ns]
# dtypes: datetime64[ns](3), float64(3), int64(10), object(22)
# memory usage: 588.9+ MB

# %%
# fix negative normal order type due to human error

data.loc[((data["order_type_code"] == "NOR") | (data["order_type_code"] == "NOH")) & (data["value_sales"] < 0), "order_type_code"] = "CRR"

# Print the updated DataFrame
print(data[data['value_sales'] < 0])
# Out:
#         accounting_date  fiscal_year  fiscal_month  calendar_year  \
# 61           2012-02-02         2012             8           2012
# 115          2012-01-17         2012             7           2012
# 176          2012-04-17         2012            10           2012
# 182          2012-02-02         2012             8           2012
# 220          2012-01-20         2012             7           2012
# ...                 ...          ...           ...            ...
# 1988192      2013-09-26         2014             3           2013
# 1988205      2013-12-10         2014             6           2013
# 1988217      2013-09-17         2014             3           2013
# 1988221      2013-08-06         2014             2           2013
# 1988291      2013-12-13         2014             6           2013
#
#          calendar_month  company_code customer_code  customer_district_code  \
# 61                    2           101     267401311                     200
# 115                   1           101     471000829                     400
# 176                   4           101     471150200                     400
# 182                   2           101     471000805                     400
# 220                   1           101     471200001                     410
# ...                 ...           ...           ...                     ...
# 1988192               9           205     510900608                     500
# 1988205              12           205     361000402                     300
# 1988217               9           205     299500514                     210
# 1988221               8           205     301600200                     300
# 1988291              12           101     310900918                     300
#
#              item_code business_area_code  ... value_sales value_cost  \
# 61       GENIE14WCDLES                LMP  ...       -6.38    -4.2428
# 115      GENIE18WCDLES                LMP  ...      -95.70   -63.6420
# 176       GENIE11WWWES                LMP  ...       -3.28    -1.9300
# 182      GENIE14WCDLBC                LMP  ...      -77.56   -59.3992
# 220      GENIE11WCDLES                OTH  ...       -2.90    -1.9300
# ...                ...                ...  ...         ...        ...
# 1988192        PN136EL                SUR  ...      -11.38   -16.0100
# 1988205         693380                LMP  ...     -119.25   -42.8500
# 1988217        PN136EL                SUR  ...      -35.84   -31.5200
# 1988221         140033                LMP  ...     -259.50     0.0000
# 1988291        SB400MH                FLD  ...    -2400.00     0.0000
#
#          value_quantity value_price_adjustment currency invoice_number  \
# 61                 -2.0                      0      AUD        2179885
# 115               -30.0                      0      AUD        2173187
# 176                -1.0                      0      AUD        2209362
# 182               -28.0                      0      AUD        2179980
# 220                -1.0                      0      AUD        2175374
# ...                 ...                    ...      ...            ...
# 1988192            -1.0                      0      AUD        2411380
# 1988205            -5.0                      0      AUD           8172
# 1988217            -2.0                      0      AUD        2407889
# 1988221             0.0                      1      AUD         644159
# 1988291             0.0                      1      AUD         645361
#
#         line_number invoice_date customer_order_number order_date
# 61                1   2012-02-02               6121135 2012-02-02
# 115               1   2012-01-17               6120746 2012-01-17
# 176               1   2012-04-17               6123288 2012-04-17
# 182               1   2012-02-02               6121163 2012-02-02
# 220               1   2012-01-20               6120866 2012-01-20
# ...             ...          ...                   ...        ...
# 1988192           3   2013-09-26               6139643 2013-09-26
# 1988205           1   2013-12-10               6142753 2013-12-10
# 1988217           1   2013-09-17               6139334 2013-09-17
# 1988221           0   2013-08-06               9068264 2013-08-06
# 1988291           0   2013-12-13               9069397 2013-12-13
#
# [109310 rows x 38 columns]

# %%
# Convert FX

# The average FX rates obtained from S&P Capital IQ
fx_rates = {
    "EUR": 0.767654,  # Euro to AUD average rate
    "NZD": 1.229117,  # NZD to AUD average rate
    "USD": 1.001749   # USD to AUD average rate
}

# Apply the conversion for value_sales in place
data.loc[data["currency"] == "NZD", "value_sales"] *= fx_rates["NZD"]
data.loc[data["currency"] == "USD", "value_sales"] *= fx_rates["USD"]
data.loc[data["currency"] == "EUR", "value_sales"] *= fx_rates["EUR"]

# Apply the conversion for value_cost in place
data.loc[data["currency"] == "NZD", "value_cost"] *= fx_rates["NZD"]
data.loc[data["currency"] == "USD", "value_cost"] *= fx_rates["USD"]
data.loc[data["currency"] == "EUR", "value_cost"] *= fx_rates["EUR"]

# %% [markdown]
# # EXPLORATION

# %%
data.groupby('value_price_adjustment')['value_sales'].describe()
# Out:
#                             count        mean          std        min    25%  \
# value_price_adjustment
# 0                       1934436.0  428.257328  2899.687455 -765100.00  25.74
# 1                         44647.0 -185.343810  4934.452200 -793541.98 -59.80
#
#                          50%     75%           max
# value_price_adjustment
# 0                       71.6  203.42  793541.98000
# 1                      -20.7   -5.50  228554.38369

# %%
data.groupby('value_price_adjustment')['value_cost'].describe()
# Out:
#                             count        mean          std        min    25%  \
# value_price_adjustment
# 0                       1934436.0  272.741836  2088.885359 -141469.52  10.58
# 1                         44647.0    0.000000     0.000000       0.00   0.00
#
#                           50%     75%       max
# value_price_adjustment
# 0                       33.67  106.64  777669.2
# 1                        0.00    0.00       0.0

# %%
data.groupby('reporting_classification').describe()
# Out:
#                          accounting_date                                 \
#                                    count                           mean
# reporting_classification
# Continuing                        563435  2012-12-24 12:36:42.572434944
# Discontinuing                    1415648  2012-12-17 10:50:10.266958848
#
#                                                                     \
#                                           min                  25%
# reporting_classification
# Continuing                2012-01-02 00:00:00  2012-06-21 00:00:00
# Discontinuing             2012-01-02 00:00:00  2012-06-18 00:00:00
#
#                                                                     \
#                                           50%                  75%
# reporting_classification
# Continuing                2012-12-17 00:00:00  2013-06-25 00:00:00
# Discontinuing             2012-12-04 00:00:00  2013-06-20 00:00:00
#
#                                                    fiscal_year               \
#                                           max  std       count         mean
# reporting_classification
# Continuing                2013-12-31 00:00:00  NaN    563435.0  2012.976915
# Discontinuing             2013-12-31 00:00:00  NaN   1415648.0  2012.964869
#
#                           ...         invoice_date      order_date  \
#                           ...                  max  std      count
# reporting_classification  ...
# Continuing                ...  2013-12-31 00:00:00  NaN     563435
# Discontinuing             ...  2013-12-31 00:00:00  NaN    1415648
#
#                                                                               \
#                                                    mean                  min
# reporting_classification
# Continuing                2012-12-19 00:03:39.436847104  2010-03-09 00:00:00
# Discontinuing             2012-12-14 12:40:55.810483456  2009-03-26 00:00:00
#
#                                                                     \
#                                           25%                  50%
# reporting_classification
# Continuing                2012-06-18 00:00:00  2012-12-12 00:00:00
# Discontinuing             2012-06-14 00:00:00  2012-12-03 00:00:00
#
#
#                                           75%                  max  std
# reporting_classification
# Continuing                2013-06-18 00:00:00  2013-12-30 00:00:00  NaN
# Discontinuing             2013-06-18 00:00:00  2013-12-30 00:00:00  NaN
#
# [2 rows x 128 columns]

# %% [markdown]
# # Create Column and Convert Data Type

# %%
df = data.copy()

# %%
columns_to_convert = ['item_type', 'item_code']
df[columns_to_convert] = df[columns_to_convert].astype(str)

# %%
# create unit price column
df['unit_price'] = df['value_sales'] / df['value_quantity']

# %%
# create profit margin column
df['profit_margin'] = (df['value_sales']-df['value_cost'])/df['value_cost']

# %% [markdown]
# # PART 2

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

import matplotlib.ticker as mtick

# %% [markdown]
# ## Create Flag Column for Analysis and Visualization Purpose

# %%
# Copy the original dataset to create a new dataset df_p2
df_p2 = df.copy()

# Define the list of order types to check
project_order_types = ["PRO", "PRD", "PMO", "CRP"]

# Add the "flag_project_order" column: set to 1 if "order_type_code" is in the list, otherwise 0
df_p2['flag_project_order'] = df_p2['order_type_code'].apply(lambda x: 1 if x in project_order_types else 0)


# Add the export_order_flag column based on the condition
df_p2['export_order_flag'] = df_p2['order_type_code'].apply(lambda x: 1 if x == "EXP" else 0)

# Add the export_order_flag column based on the condition
df_p2['fx_order_flag'] = df_p2['currency'].apply(lambda x: 1 if x != "AUD" else 0)

df_p2
# Out:
#         accounting_date  fiscal_year  fiscal_month  calendar_year  \
# 0            2012-05-09         2012            11           2012
# 1            2012-02-16         2012             8           2012
# 2            2012-05-09         2012            11           2012
# 3            2012-05-18         2012            11           2012
# 4            2012-01-09         2012             7           2012
# ...                 ...          ...           ...            ...
# 1988377      2013-11-06         2014             5           2013
# 1988378      2013-07-17         2014             1           2013
# 1988379      2013-10-21         2014             4           2013
# 1988380      2013-11-01         2014             5           2013
# 1988381      2013-09-25         2014             3           2013
#
#          calendar_month  company_code customer_code  customer_district_code  \
# 0                     5           101     411800601                     410
# 1                     2           101     361000403                     300
# 2                     5           101     361000403                     300
# 3                     5           101     565540415                     500
# 4                     1           101     565540415                     500
# ...                 ...           ...           ...                     ...
# 1988377              11           101     299480704                     200
# 1988378               7           101     500900630                     500
# 1988379              10           205     552800304                     500
# 1988380              11           101     565540407                     500
# 1988381               9           101     565540407                     500
#
#            item_code business_area_code  ... invoice_number line_number  \
# 0        GENIE8WWWBC                LMP  ...        2217887           1
# 1        GENIE8WWWBC                LMP  ...        2185745           1
# 2        GENIE8WWWBC                LMP  ...        2217807           1
# 3        GENIE8WWWBC                LMP  ...        2222758           1
# 4        GENIE8WWWBC                LMP  ...        2170374           1
# ...              ...                ...  ...            ...         ...
# 1988377  TWG114/2005                SUR  ...        2423898           1
# 1988378  SCRN236E2F4                TRO  ...        2383667           1
# 1988379     DOT92STW                OTH  ...        2419020           1
# 1988380  TWG114/2005                SUR  ...        2422799           1
# 1988381  TWG114/2005                SUR  ...        2411003           1
#
#         invoice_date customer_order_number order_date unit_price  \
# 0         2012-05-09               2865354 2012-05-09       2.60
# 1         2012-02-16               2833515 2012-02-16       3.19
# 2         2012-05-09               2864857 2012-05-08       3.35
# 3         2012-05-18               2869759 2012-05-18       3.35
# 4         2012-01-09               2819189 2012-01-09       3.19
# ...              ...                   ...        ...        ...
# 1988377   2013-11-06               3079784 2013-11-06      30.50
# 1988378   2013-07-17               3024473 2013-06-27     237.00
# 1988379   2013-10-21               3070986 2013-10-21       7.49
# 1988380   2013-11-01               3073478 2013-10-28      31.00
# 1988381   2013-09-25               3060996 2013-09-25      37.44
#
#         profit_margin flag_project_order export_order_flag fx_order_flag
# 0            0.225606                  0                 0             0
# 1            0.503724                  0                 0             0
# 2            0.579146                  0                 0             0
# 3            0.579146                  0                 0             0
# 4            0.503724                  0                 0             0
# ...               ...                ...               ...           ...
# 1988377      1.311482                  0                 0             0
# 1988378      0.738939                  0                 0             0
# 1988379      2.949380                  0                 0             0
# 1988380      1.349375                  0                 0             0
# 1988381      1.634764                  0                 0             0
#
# [1979083 rows x 43 columns]

# %%
# Calculate unit_price 
df_p2['unit_price'] = df_p2['value_sales'] / df_p2['value_quantity']

# %%
# Sales trend 
plt.figure(figsize=(16, 5) )
sns.lineplot(data=df_p2, x="calendar_month", y="value_sales", hue="calendar_year", estimator='sum',errorbar = None, style="flag_project_order")




plt.xlabel('calendar month',fontsize=15)
plt.ylabel('Sales (Million AUD)', fontsize=15)
plt.title('Monthly Sales Trend by year and Project Type Order', fontsize = 20)
plt.xticks(rotation=0, fontsize=15)
plt.yticks(rotation=0, fontsize=15)
plt.gca().yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{x / 1_000_000:,.0f}M'))
plt.xticks(ticks=range(1, 13), labels=[
    "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"
], rotation=0, fontsize=15)
plt.legend(fontsize=15) 
plt.show()

# %%
# Group by 'flag_project_order' and 'calendar_year', then sum 'value_sales'
pj_summary = df_p2.groupby(['flag_project_order', 'calendar_year'])['value_sales'].sum()

# Convert to millions
pj_summary_millions = pj_summary / 1_000_000

# Format as a string with two decimal places and add "M"
formatted_pj_summary = pj_summary_millions.apply(lambda x: f"{x:,.2f} M")

# Print the formatted result
print(formatted_pj_summary)
# Out:
# flag_project_order  calendar_year
# 0                   2012             329.66 M
#                     2013             330.71 M
# 1                   2012              86.97 M
#                     2013              72.82 M
# Name: value_sales, dtype: object

# %%
# Plotting FX currency sales

plt.figure(figsize=(16, 5) )
sns.lineplot(data=df_p2, x="calendar_month", y="value_sales", hue="calendar_year", estimator='sum',errorbar = None, style="fx_order_flag")

plt.xlabel('calendar month',fontsize=15)
plt.ylabel('Sales (Million AUD)', fontsize=15)
plt.title('Monthly Sales Trend by year and Currency', fontsize = 20)
plt.xticks(rotation=0, fontsize=15)
plt.yticks(rotation=0, fontsize=15)
plt.gca().yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{x / 1_000_000:,.0f}M'))
plt.xticks(ticks=range(1, 13), labels=[
    "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"
], rotation=0, fontsize=15)
plt.legend(fontsize=15) 

plt.show()

# %%
# Product Mix by Area

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Ensure value_sales is numeric
df_p2['value_sales'] = pd.to_numeric(data['value_sales'], errors='coerce')

# Group data by year, area, and environment group, then calculate sales
stacked_data = df_p2.groupby(['calendar_year', 'customer_district_code', 'environment_group_code']).value_sales.sum().unstack().fillna(0).reset_index()

# Define colors for each unique environment group code
unique_env_groups = stacked_data.columns[2:]
color_map = {env: plt.cm.tab20(i / len(unique_env_groups)) for i, env in enumerate(unique_env_groups)}

# Set up the plot with a larger figure size
fig, ax = plt.subplots(figsize=(20, 10))

# Define bar width for side-by-side bars per year
bar_width = 0.35
years = sorted(stacked_data['calendar_year'].unique())
edge_colors = {years[0]: 'white', years[1]: 'red'}  # Define edge colors for each year

# Loop through each year and plot stacked bars for each area
for i, year in enumerate(years):
    # Filter data for the current year
    year_data = stacked_data[stacked_data['calendar_year'] == year]
    
    # Set x positions with offset for each year
    x_positions = np.arange(len(year_data['customer_district_code'])) + (i - 0.5) * bar_width

    # Initialize bottom positions for stacking
    bottom_values = [0] * len(x_positions)
    
    # Plot each environment group as a stack in the bars, with same color and different edge for each year
    for environment_group_code in unique_env_groups:
        ax.bar(
            x_positions, 
            year_data[environment_group_code], 
            width=bar_width, 
            bottom=bottom_values, 
            color=color_map[environment_group_code],    # Consistent color for each environment group
            edgecolor=edge_colors[year],                # Different edge color for each year
            label=f"{environment_group_code}" if i == 0 else "",  # Only label environment group once
        )
        # Update bottom position for the next stack
        bottom_values += year_data[environment_group_code].values

# Customizing plot aesthetics
plt.xlabel('Customer District Code', fontsize=20)
plt.ylabel('Sales (Million AUD)', fontsize=20)
plt.title('Sales by Customer District Environment Group Mix, and Year Comparison', fontsize=25)
plt.xticks(np.arange(len(year_data['customer_district_code'])), year_data['customer_district_code'], rotation=0, ha='right', fontsize=20)

plt.xticks(rotation=0, fontsize=20)
plt.yticks(rotation=0, fontsize=20)
plt.gca().yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{x / 1_000_000:,.0f}M'))

# Place the legend in the top-right corner, outside the plot area
plt.legend(title="Environment Group Code", loc="upper left", bbox_to_anchor=(1.05, 1), fontsize=15)

# Adjust layout to avoid cutting off the legend
plt.tight_layout()
plt.show()

# %%
print(years)
# Out:
# [2012, 2013]

# %%
# Plot Quanitity

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Ensure value_sales is numeric
data['value_sales'] = pd.to_numeric(data['value_sales'], errors='coerce')

# Group data by year, area, and environment group, then calculate sales
stacked_data = data.groupby(['calendar_year', 'customer_district_code', 'environment_group_code']).value_quantity.sum().unstack().fillna(0).reset_index()

# Define colors for each unique environment group code
unique_env_groups = stacked_data.columns[2:]
color_map = {env: plt.cm.tab20(i / len(unique_env_groups)) for i, env in enumerate(unique_env_groups)}

# Set up the plot with a larger figure size
fig, ax = plt.subplots(figsize=(20, 10))

# Define bar width for side-by-side bars per year
bar_width = 0.35
years = sorted(stacked_data['calendar_year'].unique())
edge_colors = {years[0]: 'white', years[1]: 'red'}  # Define edge colors for each year

# Loop through each year and plot stacked bars for each area
for i, year in enumerate(years):
    # Filter data for the current year
    year_data = stacked_data[stacked_data['calendar_year'] == year]
    
    # Set x positions with offset for each year
    x_positions = np.arange(len(year_data['customer_district_code'])) + (i - 0.5) * bar_width

    # Initialize bottom positions for stacking
    bottom_values = [0] * len(x_positions)
    
    # Plot each environment group as a stack in the bars, with same color and different edge for each year
    for environment_group_code in unique_env_groups:
        ax.bar(
            x_positions, 
            year_data[environment_group_code], 
            width=bar_width, 
            bottom=bottom_values, 
            color=color_map[environment_group_code],    # Consistent color for each environment group
            edgecolor=edge_colors[year],                # Different edge color for each year
            label=f"{environment_group_code}" if i == 0 else "",  # Only label environment group once
        )
        # Update bottom position for the next stack
        bottom_values += year_data[environment_group_code].values

# Customizing plot aesthetics

plt.xticks(np.arange(len(year_data['customer_district_code'])), year_data['customer_district_code'], rotation=45, ha='right', fontsize=20)

# Customizing plot aesthetics
plt.xlabel('Customer District Code', fontsize=20)
plt.ylabel('Quanity (Million)', fontsize=20)
plt.title('Quanity Sold by Area, Environment Group Mix, and Year Comparison', fontsize=25)

plt.xticks(rotation=0, fontsize=20)
plt.yticks(rotation=0, fontsize=20)
plt.gca().yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{x / 1_000_000:,.0f}M'))

# Place the legend in the top-right corner, outside the plot area
plt.legend(title="Environment Group Code", loc="upper left", bbox_to_anchor=(1.05, 1), fontsize=15)

# Place the legend in the top-right corner, outside the plot area
plt.legend(title="Environment Group Code", loc="upper left", bbox_to_anchor=(1.05, 1), fontsize=20)

# Adjust layout to avoid cutting off the legend
plt.tight_layout()
plt.show()

# %%
# Create the grouping of business code for visualization purpose

# Define list of codes to check against
bus_codes_grouping = ['SUR', 'LMP', 'COM', 'RWY', 'DLT', 'TRO', 'FLD', 'OTH', 'HLB', 'SAE']

# Create new column with conditional logic
df_p2['bus_area_group'] = df_p2['business_area_code'].apply(lambda x: x if x in bus_codes_grouping  else 'Others')

# %%
sns.catplot(data=data, x="value_sales", y="business_area_code", hue="calendar_year", kind="bar", estimator='sum',errorbar = None
)

# %%
top_bus_code = df_p2.groupby("business_area_code")['value_sales'].sum()
top_bus_code = top_bus_code.sort_values(ascending=False)
top_bus_code
# Out:
# business_area_code
# SUR    1.742617e+08
# LMP    1.007670e+08
# COM    8.042733e+07
# RWY    7.924635e+07
# DLT    7.496518e+07
# TRO    7.143937e+07
# FLD    6.717938e+07
# OTH    5.736310e+07
# HLB    2.854144e+07
# SAE    2.676963e+07
# URB    1.635928e+07
# TAL    1.522189e+07
# EXL    5.767577e+06
# 920    4.497697e+06
# PEN    4.320405e+06
# LCP    2.866476e+06
# 999    2.583532e+06
# 940    2.192052e+06
# 980    1.576176e+06
# 910    1.229716e+06
# 950    9.150049e+05
# 945    5.806099e+05
# 970    4.388225e+05
# 960    2.973566e+05
# IAE    1.190152e+05
# IAI    9.250843e+04
# 930    7.411761e+04
# 985    6.861807e+04
# Name: value_sales, dtype: float64

# %%
# Product by Project Type Order
import seaborn as sns

# Calculate the order of `bus_area_group` based on the sum of `value_sales`
order = df_p2.groupby("bus_area_group")["value_sales"].sum().sort_values(ascending=False).index

# Create the catplot with bars sorted in descending order
g = sns.catplot(
    data=df_p2, 
    x="value_sales", 
    y="bus_area_group", 
    hue="calendar_year", 
    kind="bar", 
    estimator='sum', 
    errorbar=None, 
    col="flag_project_order",
    
    order=order  # Apply the sorted order here
)
# Customizing plot aesthetics
# Loop through each axis to apply formatting

for ax in g.axes.flat:
     #Format X-axis to show values in million
    ax.xaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{x / 1_000_000:,.0f}M'))
    #ax.set_ylabel("Business Area Group", fontsize=20)
    #ax.set_yticklabels(ax.get_yticklabels(), fontsize=20) 
    # Adjust legend font size
    #ax.legend(fontsize=20)
    #for label in ax.get_yticklabels():
        #label.set_fontsize(10)

# Set an overall title for the figure (optional)
g.fig.suptitle('Compare Product Mix between Project VS Non Project order', y=1.05)  # Adjust y for spacing

plt.show()

# %%
import seaborn as sns

# Calculate the order of `bus_area_group` based on the sum of `value_sales`
order2 = df_p2.groupby("bus_area_group")["value_sales"].sum().sort_values(ascending=False).index

# Create the catplot with bars sorted in descending order
f = sns.catplot(
    data=df_p2, 
    x="value_sales", 
    y="bus_area_group", 
    hue="calendar_year", 
    kind="bar", 
    estimator='sum', 
    errorbar=None, 
    col="fx_order_flag",
    
    order=order2  # Apply the sorted order here
)

for ax in f.axes.flat:
     #Format X-axis to show values in million
    ax.xaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{x / 1_000_000:,.0f}M'))
    #ax.set_ylabel("Business Area Group", fontsize=20)
    #ax.set_yticklabels(ax.get_yticklabels(), fontsize=20) 
    # Adjust legend font size
    #ax.legend(fontsize=20)
    #for label in ax.get_yticklabels():
        #label.set_fontsize(10)

# Set an overall title for the figure (optional)
f.fig.suptitle('Compare Product Mix between AUD order VS other currency', y=1.05)  # Adjust y for spacing
# Out:
# Text(0.5, 1.05, 'Compare Product Mix between AUD order VS other currency')

# %%
df_p2['profit'] = df_p2['value_sales'] - df_p2['value_cost']

# %%
import seaborn as sns

# Calculate the order of `bus_area_group` based on the sum of `value_sales`
order3 = df_p2.groupby("bus_area_group")["profit"].sum().sort_values(ascending=False).index

# Create the catplot with bars sorted in descending order
h=sns.catplot(
    data=df_p2, 
    x="profit", 
    y="bus_area_group", 
    hue="calendar_year", 
    kind="bar", 
    estimator='sum', 
    errorbar=None, 
    col="flag_project_order",
    
    order=order3  # Apply the sorted order here
)

for ax in h.axes.flat:
     #Format X-axis to show values in million
    ax.xaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{x / 1_000_000:,.0f}M'))
    #ax.set_ylabel("Business Area Group", fontsize=20)
    #ax.set_yticklabels(ax.get_yticklabels(), fontsize=20) 
    # Adjust legend font size
    #ax.legend(fontsize=20)
    #for label in ax.get_yticklabels():
        #label.set_fontsize(10)

f.fig.suptitle('Compare Product Mix between AUD order VS other currency', y=1.05)  # Adjust y for spacing
# Out:
# Text(0.5, 1.05, 'Compare Product Mix between AUD order VS other currency')

# %% [markdown]
# #  Profit Margin

# %%
df_p2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1979083 entries, 0 to 1988381
# Data columns (total 45 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   accounting_date           datetime64[ns]
#  1   fiscal_year               int64
#  2   fiscal_month              int64
#  3   calendar_year             int64
#  4   calendar_month            int64
#  5   company_code              int64
#  6   customer_code             object
#  7   customer_district_code    int64
#  8   item_code                 object
#  9   business_area_code        object
#  10  item_group_code           object
#  11  item_class_code           object
#  12  item_type                 object
#  13  bonus_group_code          object
#  14  environment_group_code    object
#  15  technology_group_code     object
#  16  commission_group_code     object
#  17  reporting_classification  object
#  18  light_source              object
#  19  warehouse_code            object
#  20  abc_class_code            object
#  21  abc_class_volume          object
#  22  business_chain_l1_code    object
#  23  business_chain_l1_name    object
#  24  contact_method_code       object
#  25  salesperson_code          object
#  26  order_type_code           object
#  27  market_segment            object
#  28  value_sales               float64
#  29  value_cost                float64
#  30  value_quantity            float64
#  31  value_price_adjustment    int64
#  32  currency                  object
#  33  invoice_number            int64
#  34  line_number               int64
#  35  invoice_date              datetime64[ns]
#  36  customer_order_number     object
#  37  order_date                datetime64[ns]
#  38  unit_price                float64
#  39  profit_margin             float64
#  40  flag_project_order        int64
#  41  export_order_flag         int64
#  42  fx_order_flag             int64
#  43  bus_area_group            object
#  44  profit                    float64
# dtypes: datetime64[ns](3), float64(6), int64(12), object(24)
# memory usage: 694.6+ MB

# %%
# Step 1: Perform the aggregation to calculate value_sales, value_cost, profit, and profit_margin

df_agg = df_p2.groupby(
    ['invoice_number', 'calendar_year', 'calendar_month', 'customer_district_code', 
     'business_area_code', 'bonus_group_code', 'environment_group_code', 'technology_group_code', 
     'commission_group_code', 'abc_class_code', 'abc_class_volume', 'flag_project_order', 'order_type_code',
     'export_order_flag', 'currency'], as_index=False
).agg({
    'value_sales': 'sum',
    'value_cost': 'sum',
    
})

# %%
# recheck if aggregation is correct

df_p2_sales = df_p2['value_sales'].sum()
print (f'df_p2 sales =',df_p2_sales)
# Out:
# df_p2 sales = 820161347.2787639

# %%
df_p2_invoice = df_p2['invoice_number'].nunique()
df_p2_invoice
# Out:
# 619272

# %%
data_invoice = data['invoice_number'].nunique()
data_invoice
# Out:
# 619272

# %%
data['invoice_number'].count()
# Out:
# 1979083

# %%
df_agg_sales = df_agg['value_sales'].sum()
print (f'df_agg_sales =', df_agg_sales)
# Out:
# df_agg_sales = 820161347.2787635

# %%
df_agg_invoice = df_agg['invoice_number'].nunique()
df_agg_invoice
# Out:
# 619272

# %%
df_agg_inv_count = df_agg['invoice_number'].count()
df_agg_inv_count
# Out:
# 1501227

# %%
# Create Aggregate Data at Cust District Code

# %%
df_agg_custdistrict = df_p2.groupby(
    [ 'calendar_year', 'customer_district_code', 
  ], as_index=False
).agg({
    'value_sales': 'sum',
    'value_cost': 'sum',
    
})

# Create a column profit margin
df_agg_custdistrict['%profit_margin'] = df_agg_custdistrict['value_sales']/df_agg_custdistrict['value_cost']-1
df_agg_custdistrict['profit'] = df_agg_custdistrict['value_sales']-df_agg_custdistrict['value_cost']
df_agg_custdistrict.head(5)
# Out:
#    calendar_year  customer_district_code  value_sales    value_cost  \
# 0           2012                     200  72955060.95  4.106377e+07
# 1           2012                     210  10568410.95  5.653891e+06
# 2           2012                     300  66088689.19  3.671199e+07
# 3           2012                     310   5143453.60  2.747574e+06
# 4           2012                     400  53825890.57  3.031964e+07
#
#    %profit_margin        profit
# 0        0.776628  3.189129e+07
# 1        0.869228  4.914520e+06
# 2        0.800193  2.937670e+07
# 3        0.871998  2.395880e+06
# 4        0.775281  2.350625e+07

# %%
# check with original data
data.groupby(['calendar_year','customer_district_code'])['value_cost'].sum()
# Out:
# calendar_year  customer_district_code
# 2012           200                       4.106377e+07
#                210                       5.653891e+06
#                300                       3.671199e+07
#                310                       2.747574e+06
#                400                       3.031964e+07
#                410                       6.673687e+06
#                500                       1.510882e+07
#                510                       3.041025e+06
#                520                       1.349429e+06
#                530                       2.533484e+06
#                535                       1.939073e+06
#                540                       5.975995e+06
#                545                       2.557618e+03
#                600                       3.133058e+07
#                710                       9.003643e+06
#                720                       6.836489e+07
# 2013           200                       3.751250e+07
#                210                       4.793716e+06
#                300                       3.716563e+07
#                310                       2.248947e+06
#                400                       3.347271e+07
#                410                       5.821518e+06
#                500                       1.464176e+07
#                510                       3.716862e+06
#                520                       1.327198e+06
#                530                       2.009827e+06
#                535                       1.405105e+06
#                540                       7.068963e+06
#                545                       3.269560e+03
#                600                       2.734932e+07
#                710                       1.184020e+07
#                720                       7.540405e+07
# Name: value_cost, dtype: float64

# %%
sns.catplot(data = df_agg_custdistrict, x='customer_district_code', y ='%profit_margin', kind = 'bar', hue='calendar_year', estimator = 'sum',
           height=5,aspect=1.5 )
plt.xlabel("Customer district code")
plt.ylabel("%Profit Margin")
plt.title("Profit Margin by Customer District (include product return/refund/price adj)")
#plt.xticks(rotation=0, fontsize=10)

#plt.legend()
plt.show()

# %%
# add cust level
df_agg_custdistrict_bycust = df_p2.groupby(
    [ 'calendar_year', 'customer_district_code', 'customer_code'
  ], as_index=False
).agg({
    'value_sales': 'sum',
    'value_cost': 'sum',
    
})

# Create a column profit margin
df_agg_custdistrict_bycust['%profit_margin'] = df_agg_custdistrict_bycust['value_sales']/df_agg_custdistrict_bycust['value_cost']-1
df_agg_custdistrict_bycust['profit'] = df_agg_custdistrict_bycust['value_sales']-df_agg_custdistrict_bycust['value_cost']
df_agg_custdistrict_bycust
# Out:
#       calendar_year  customer_district_code customer_code    value_sales  \
# 0              2012                     200     109900100  148351.330000
# 1              2012                     200     146000100   40500.000000
# 2              2012                     200     147000100  610280.150000
# 3              2012                     200     147500100    1534.610000
# 4              2012                     200     148500100     859.900000
# ...             ...                     ...           ...            ...
# 7801           2013                     720     Z81002401   64597.682002
# 7802           2013                     720     Z81002501   72915.829629
# 7803           2013                     720     Z90000301       0.000000
# 7804           2013                     720     Z90000601   58870.500720
# 7805           2013                     720     Z90001301   11154.236775
#
#          value_cost  %profit_margin         profit
# 0          0.000000             inf  148351.330000
# 1      22796.540000        0.776585   17703.460000
# 2     491602.930000        0.241409  118677.220000
# 3        762.896000        1.011559     771.714000
# 4        553.630000        0.553203     306.270000
# ...             ...             ...            ...
# 7801  105543.942224       -0.387955  -40946.260222
# 7802   82979.789108       -0.121282  -10063.959479
# 7803   10936.506073       -1.000000  -10936.506073
# 7804   31293.258765        0.881252   27577.241955
# 7805       0.000000             inf   11154.236775
#
# [7806 rows x 7 columns]

# %%
sns.boxplot(data=df_agg_custdistrict_bycust, x='customer_district_code', y='%profit_margin', hue="calendar_year")
plt.show()

# %%
from matplotlib.ticker import FuncFormatter
sns.scatterplot(data=df_agg_custdistrict_bycust, x='value_sales', y='%profit_margin', hue="customer_district_code")
plt.xlabel("Sales")
plt.ylabel("Profit Margin (times)")
plt.title("Profit Margin by Customer District by customer")
plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x / 1e6:.1f}M'))

plt.show()

# %%
df_agg_custdistrict_bycust_1 = df_agg_custdistrict_bycust[df_agg_custdistrict_bycust['%profit_margin'] <2]

# %%
sns.scatterplot(data=df_agg_custdistrict_bycust_1, x='value_sales', y='%profit_margin', hue="customer_district_code", palette = "bright")
plt.xlabel("Sales")
plt.ylabel("Profit Margin")
plt.title("Profit Margin by Customer District by customer")
plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x / 1e6:.1f}M'))

plt.show()

# %% [markdown]
# # Profit Margin By Currency

# %%
# Profit Margin by FX

df_agg_fx = df_p2.groupby(
    [ 'calendar_year', 'currency', 'customer_code', 'customer_district_code',
  ], as_index=False
).agg({
    'value_sales': 'sum',
    'value_cost': 'sum',
    
})

# Create a column profit margin
df_agg_fx ['%profit_margin'] = df_agg_fx['value_sales']/df_agg_fx['value_cost']-1
df_agg_fx ['profit'] = df_agg_fx['value_sales']-df_agg_fx['value_cost']
df_agg_fx
# Out:
#       calendar_year currency customer_code  customer_district_code  \
# 0              2012      AUD     100210100                     710
# 1              2012      AUD     100230100                     710
# 2              2012      AUD     100250200                     720
# 3              2012      AUD     100270100                     710
# 4              2012      AUD     100296100                     710
# ...             ...      ...           ...                     ...
# 7802           2013      USD     829920100                     710
# 7803           2013      USD     848330801                     710
# 7804           2013      USD     851910100                     720
# 7805           2013      USD     857709100                     710
# 7806           2013      USD     860900200                     720
#
#         value_sales     value_cost  %profit_margin        profit
# 0      66374.080000   52294.880000        0.269227  14079.200000
# 1      36742.000000   25852.727200        0.421204  10889.272800
# 2        656.400000     558.600000        0.175081     97.800000
# 3       1234.710000     489.576600        1.521996    745.133400
# 4        180.000000      91.740000        0.962067     88.260000
# ...             ...            ...             ...           ...
# 7802    3754.134517    3326.527939        0.128544    427.606578
# 7803   30110.821879   27166.671551        0.108374   2944.150328
# 7804  379274.202405  358517.658594        0.057895  20756.543812
# 7805   15992.982890    7541.747486        1.120594   8451.235404
# 7806  595494.962250  542170.558202        0.098354  53324.404048
#
# [7807 rows x 8 columns]

# %%
sns.boxplot(data=df_agg_fx, x='currency', y='%profit_margin', hue="calendar_year")
plt.show()

# %%
df_agg_fx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7807 entries, 0 to 7806
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   calendar_year           7807 non-null   int64
#  1   currency                7807 non-null   object
#  2   customer_code           7807 non-null   object
#  3   customer_district_code  7807 non-null   int64
#  4   value_sales             7807 non-null   float64
#  5   value_cost              7807 non-null   float64
#  6   %profit_margin          7799 non-null   float64
#  7   profit                  7807 non-null   float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 488.1+ KB

# %%
sns.boxplot(data=df_agg_fx, x='currency', y='%profit_margin', hue="calendar_year")
plt.show()

# %%
sns.boxplot(data=df_agg_fx, x='currency', y='%profit_margin')
plt.show()

# %%
# Profit Margin by FX

df_agg_fx_summary = df_p2.groupby(
    [ 'calendar_year', 'currency', 
  ], as_index=False
).agg({
    'value_sales': 'sum',
    'value_cost': 'sum',
    
})

# Create a column profit margin
df_agg_fx_summary ['%profit_margin'] = df_agg_fx_summary ['value_sales']/df_agg_fx_summary ['value_cost']-1
df_agg_fx_summary ['profit'] = df_agg_fx_summary ['value_sales']-df_agg_fx_summary ['value_cost']
df_agg_fx_summary
# Out:
#    calendar_year currency   value_sales    value_cost  %profit_margin  \
# 0           2012      AUD  3.916670e+08  2.463429e+08        0.589926
# 1           2012      EUR  6.746844e+04  6.662618e+04        0.012642
# 2           2012      NZD  2.113760e+07  1.189599e+07        0.776868
# 3           2012      USD  3.754996e+06  3.514531e+06        0.068420
# 4           2013      AUD  3.782605e+08  2.500468e+08        0.512759
# 5           2013      NZD  2.117854e+07  1.214677e+07        0.743553
# 6           2013      USD  4.095253e+06  3.587961e+06        0.141387
#
#          profit
# 0  1.453241e+08
# 1  8.422667e+02
# 2  9.241610e+06
# 3  2.404653e+05
# 4  1.282137e+08
# 5  9.031772e+06
# 6  5.072919e+05

# %%
# Profit Margin by Currency

sns.catplot(data = df_agg_fx_summary , x='currency', y ='%profit_margin', kind = 'bar', hue='calendar_year', estimator = 'sum',
           height=5,aspect=1.5 )
plt.xlabel("Currency")
plt.ylabel("Profit Margin (times)")
plt.title("Profit Margin by Currency")
#plt.xticks(rotation=0, fontsize=10)

plt.legend()
plt.show()

# %%
sns.catplot(data = df_agg_fx_summary , x='currency', y ='%profit_margin', kind = 'bar', hue='calendar_year', estimator = 'sum',
           height=5,aspect=1.5 )
plt.xlabel("Currency")
plt.ylabel("Profit Margin (times)")
plt.title("Profit Margin by Currency")
#plt.xticks(rotation=0, fontsize=10)

plt.legend()
plt.show()

# %%
# Selecting USD transaction
usd = df_p2[df_p2['currency'] == "USD"]

# group by customer district to check which district have USD transaction
usd.groupby(['currency','customer_district_code'])['value_sales'].describe()
# Out:
#                                  count          mean           std  \
# currency customer_district_code
# USD      710                     342.0   9778.763079  21439.200054
#          720                     333.0  13531.267119  20068.501881
#
#                                           min          25%          50%  \
# currency customer_district_code
# USD      710                    -34494.054769  1666.469566  4548.661719
#          720                    -70469.976798  1914.452531  6611.543400
#
#                                           75%            max
# currency customer_district_code
# USD      710                     10234.498886  228554.383690
#          720                     19046.844769  109519.374952

# %%
df_p2['customer_code'].nunique()
# Out:
# 4480

# %%
# Currency by Customer District
df_grouped = df.groupby(['customer_district_code', 'currency'])['value_sales'].sum().unstack(fill_value=0)

# Step 2: Plot the stacked bar chart using data.plot
df_grouped.plot(kind='bar', stacked=True, figsize=(10, 6))

# Step 3: Customize the plot
plt.title('Sales by Customer District and Currencies')
plt.xlabel('Customer District')
plt.ylabel('Sales Value')
plt.legend(title='Currency')
plt.xticks(rotation=45, ha='right')  # Rotate x-ticks for better readability
plt.gca().yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{x / 1_000_000:,.0f}M'))

# Show plot
plt.tight_layout()
plt.show()

# %%
# Profit Margin by FX

df_agg_monthly_prof = df_p2.groupby(
    [ 'calendar_year', 'calendar_month', 'flag_project_order'
  ], as_index=False
).agg({
    'value_sales': 'sum',
    'value_cost': 'sum',
    
})

# Create a column profit margin
df_agg_monthly_prof['%profit_margin'] = df_agg_monthly_prof ['value_sales']/df_agg_monthly_prof ['value_cost']-1
df_agg_monthly_prof ['profit'] = df_agg_monthly_prof ['value_sales']-df_agg_monthly_prof['value_cost']
df_agg_monthly_prof
# Out:
#     calendar_year  calendar_month  flag_project_order   value_sales  \
# 0            2012               1                   0  1.979641e+07
# 1            2012               1                   1  3.970669e+06
# 2            2012               2                   0  2.855748e+07
# 3            2012               2                   1  9.009324e+06
# 4            2012               3                   0  2.930861e+07
# 5            2012               3                   1  9.238606e+06
# 6            2012               4                   0  2.631925e+07
# 7            2012               4                   1  8.129072e+06
# 8            2012               5                   0  3.454137e+07
# 9            2012               5                   1  7.537242e+06
# 10           2012               6                   0  2.828220e+07
# 11           2012               6                   1  7.535409e+06
# 12           2012               7                   0  3.008210e+07
# 13           2012               7                   1  8.857898e+06
# 14           2012               8                   0  3.139952e+07
# 15           2012               8                   1  7.317715e+06
# 16           2012               9                   0  2.711102e+07
# 17           2012               9                   1  6.993561e+06
# 18           2012              10                   0  2.788206e+07
# 19           2012              10                   1  6.359322e+06
# 20           2012              11                   0  2.793928e+07
# 21           2012              11                   1  6.865606e+06
# 22           2012              12                   0  1.844007e+07
# 23           2012              12                   1  5.153255e+06
# 24           2013               1                   0  1.849723e+07
# 25           2013               1                   1  3.975486e+06
# 26           2013               2                   0  2.515905e+07
# 27           2013               2                   1  6.248658e+06
# 28           2013               3                   0  2.682039e+07
# 29           2013               3                   1  7.816454e+06
# 30           2013               4                   0  2.778302e+07
# 31           2013               4                   1  5.691669e+06
# 32           2013               5                   0  3.103916e+07
# 33           2013               5                   1  5.720772e+06
# 34           2013               6                   0  3.225003e+07
# 35           2013               6                   1  4.888484e+06
# 36           2013               7                   0  3.115880e+07
# 37           2013               7                   1  6.156259e+06
# 38           2013               8                   0  3.143712e+07
# 39           2013               8                   1  6.540444e+06
# 40           2013               9                   0  3.025784e+07
# 41           2013               9                   1  7.355190e+06
# 42           2013              10                   0  2.915357e+07
# 43           2013              10                   1  6.485482e+06
# 44           2013              11                   0  2.843105e+07
# 45           2013              11                   1  7.374218e+06
# 46           2013              12                   0  1.872746e+07
# 47           2013              12                   1  4.566462e+06
#
#       value_cost  %profit_margin        profit
# 0   1.259055e+07        0.572323  7.205857e+06
# 1   2.326376e+06        0.706805  1.644294e+06
# 2   1.890792e+07        0.510345  9.649564e+06
# 3   5.172083e+06        0.741914  3.837241e+06
# 4   1.861088e+07        0.574810  1.069773e+07
# 5   5.283597e+06        0.748545  3.955008e+06
# 6   1.689654e+07        0.557671  9.422708e+06
# 7   4.672457e+06        0.739785  3.456614e+06
# 8   2.227854e+07        0.550432  1.226282e+07
# 9   4.392380e+06        0.715981  3.144862e+06
# 10  1.764363e+07        0.602969  1.063857e+07
# 11  4.314879e+06        0.746378  3.220530e+06
# 12  1.951891e+07        0.541177  1.056318e+07
# 13  5.101817e+06        0.736224  3.756082e+06
# 14  2.030922e+07        0.546072  1.109029e+07
# 15  4.292705e+06        0.704686  3.025010e+06
# 16  1.753230e+07        0.546347  9.578715e+06
# 17  3.929436e+06        0.779787  3.064125e+06
# 18  1.780598e+07        0.565881  1.007607e+07
# 19  3.629694e+06        0.752027  2.729628e+06
# 20  1.802683e+07        0.549872  9.912452e+06
# 21  3.926408e+06        0.748572  2.939198e+06
# 22  1.163332e+07        0.585108  6.806749e+06
# 23  3.023582e+06        0.704354  2.129673e+06
# 24  1.184802e+07        0.561208  6.649206e+06
# 25  2.323002e+06        0.711357  1.652484e+06
# 26  1.643157e+07        0.531141  8.727480e+06
# 27  3.657886e+06        0.708270  2.590772e+06
# 28  1.759147e+07        0.524625  9.228920e+06
# 29  4.639470e+06        0.684773  3.176984e+06
# 30  1.768461e+07        0.571028  1.009841e+07
# 31  3.305837e+06        0.721703  2.385832e+06
# 32  1.999373e+07        0.552445  1.104544e+07
# 33  3.280429e+06        0.743910  2.440343e+06
# 34  2.096002e+07        0.538645  1.129001e+07
# 35  2.838754e+06        0.722053  2.049730e+06
# 36  2.113997e+07        0.473928  1.001882e+07
# 37  3.614952e+06        0.702999  2.541306e+06
# 38  2.171208e+07        0.447909  9.725038e+06
# 39  3.982704e+06        0.642212  2.557740e+06
# 40  2.115643e+07        0.430196  9.101415e+06
# 41  4.532600e+06        0.622731  2.822591e+06
# 42  2.138349e+07        0.363368  7.770082e+06
# 43  3.911264e+06        0.658155  2.574218e+06
# 44  1.971871e+07        0.441831  8.712340e+06
# 45  4.438059e+06        0.661586  2.936159e+06
# 46  1.289648e+07        0.452138  5.830985e+06
# 47  2.740027e+06        0.666575  1.826434e+06

# %%
# Profit by Month
sns.catplot(data = df_agg_monthly_prof , x='calendar_month', y ='%profit_margin', kind = 'bar', hue='calendar_year', estimator = "mean", col='flag_project_order',
           height=5,aspect=1.5 )
plt.xlabel("month")
plt.ylabel("%Profit Margin")
plt.title("Profit Margin by month")
#plt.xticks(rotation=0, fontsize=10)

plt.legend()
plt.show()

# %% [markdown]
# # SECTION 3: T-TEST

# %% [markdown]
# # CHURN

# %%
#create a column time gap between the order date and invoice date

df_p2['time_gap'] = df_p2['invoice_date'] - df_p2['order_date']

# %%
import numpy as np
import pandas as pd

# Sample DataFrame setup for demonstration
# Get the latest order date per customer
churn = df_p2.groupby('customer_code').agg({'order_date': 'max'}).rename(columns={'order_date': 'latest_order_date'})

# Merge the latest order date back to the original DataFrame
df_p2 = df_p2.merge(churn, on='customer_code', how='left')

# Define the cutoff date for churn
cutoff_date = pd.to_datetime("2013-06-30")

# Apply the churn flag condition
df_p2['churn_flag'] = np.where(df_p2['latest_order_date'] <= cutoff_date, 1, 0)

# Drop the 'latest_order_date' column if it's no longer needed
df_p2.drop(columns=['latest_order_date'], inplace=True)

print(df_p2.head())
# Out:
#   accounting_date  fiscal_year  fiscal_month  calendar_year  calendar_month  \
# 0      2012-05-09         2012            11           2012               5
# 1      2012-02-16         2012             8           2012               2
# 2      2012-05-09         2012            11           2012               5
# 3      2012-05-18         2012            11           2012               5
# 4      2012-01-09         2012             7           2012               1
#
#    company_code customer_code  customer_district_code    item_code  \
# 0           101     411800601                     410  GENIE8WWWBC
# 1           101     361000403                     300  GENIE8WWWBC
# 2           101     361000403                     300  GENIE8WWWBC
# 3           101     565540415                     500  GENIE8WWWBC
# 4           101     565540415                     500  GENIE8WWWBC
#
#   business_area_code  ... order_date unit_price profit_margin  \
# 0                LMP  ... 2012-05-09       2.60      0.225606
# 1                LMP  ... 2012-02-16       3.19      0.503724
# 2                LMP  ... 2012-05-08       3.35      0.579146
# 3                LMP  ... 2012-05-18       3.35      0.579146
# 4                LMP  ... 2012-01-09       3.19      0.503724
#
#   flag_project_order export_order_flag fx_order_flag bus_area_group   profit  \
# 0                  0                 0             0            LMP  40.2024
# 1                  0                 0             0            LMP  12.8232
# 2                  0                 0             0            LMP  14.7432
# 3                  0                 0             0            LMP   7.3716
# 4                  0                 0             0            LMP   6.4116
#
#   time_gap churn_flag
# 0   0 days          0
# 1   0 days          0
# 2   1 days          0
# 3   0 days          0
# 4   0 days          0
#
# [5 rows x 47 columns]

# %%
df_churn = df_p2[df_p2['churn_flag']==1] 
print(df_churn['customer_code'].count())
# Out:
# 36938

# %%
# Define the specific order_type_codes that represent returns
return_codes = ['CDG', 'CRR', 'WDC', 'CPR', 'ZCG']

# Create a new 'return' column in df_churn
df_churn['return'] = df_churn.apply(lambda row: row['value_sales'] if row['order_type_code'] in return_codes else 0, axis=1)

# Aggregate data to calculate total value_sales, total_return, and %return_to_sales
aggregated_df = df_churn.groupby(['customer_code', 'calendar_year']).agg(
    value_sales=('value_sales', 'sum'),         # Total sales per customer per year
    total_return=('return', lambda x: abs(x.sum()))  # Sum of returns per customer per year, taking absolute value
).reset_index()

# Calculate %return_to_sales (sales is original sales, thus, sales excludes return value)
aggregated_df['%return_to_sales'] = (aggregated_df['total_return'] / (aggregated_df['value_sales']+aggregated_df['total_return']))

# Select only the required columns for the output
churn_return_df = aggregated_df[['customer_code', 'calendar_year', 'value_sales','total_return', '%return_to_sales']]

# Display the result
print(churn_return_df)
# Out:
#      customer_code  calendar_year    value_sales  total_return  \
# 0        100230100           2012   36742.000000          0.00
# 1        100230100           2013     448.920000          0.00
# 2        100296100           2012     180.000000          0.00
# 3        101296100           2012  276669.100000      12828.39
# 4        101891100           2012  568526.000000       3336.00
# ...            ...            ...            ...           ...
# 1275     ZI8007501           2012    9261.150772          0.00
# 1276     ZI8008001           2013     832.063044          0.00
# 1277     ZI9000103           2013     987.288230          0.00
# 1278     ZI9500101           2012     325.888081          0.00
# 1279     ZI9500102           2012     143.708360          0.00
#
#       %return_to_sales
# 0             0.000000
# 1             0.000000
# 2             0.000000
# 3             0.044313
# 4             0.005834
# ...                ...
# 1275          0.000000
# 1276          0.000000
# 1277          0.000000
# 1278          0.000000
# 1279          0.000000
#
# [1280 rows x 5 columns]

# %%
# drop customer with no product return  as we focus on customer with product return only
# drop negative value sales because they are inactive for over 2 years and not our focus 

churn_return_df = churn_return_df[(churn_return_df['value_sales'] >0) & (churn_return_df['total_return'] >0)]

# %%
churn_return_df.describe()
# Out:
#        calendar_year    value_sales   total_return  %return_to_sales
# count     201.000000     201.000000     201.000000        201.000000
# mean     2012.159204   35523.807057    4816.116329          0.132530
# std         0.366780   72363.528795   26143.595673          0.168275
# min      2012.000000      61.520000       5.000000          0.000867
# 25%      2012.000000    2059.930000     195.700000          0.019414
# 50%      2012.000000   12672.970614     691.009577          0.065123
# 75%      2012.000000   33728.320000    1845.273352          0.172605
# max      2013.000000  568526.000000  269559.566693          0.825952

# %%
# Plot Histogram
sns.histplot(data = churn_return_df, x= '%return_to_sales')

plt.xlabel("% Product Return Amount / Sales", fontsize=15)
plt.ylabel("number of customer", fontsize=15)
plt.title("Churn Customer Distribution of %Product Return Amount/Sales", fontsize=15)
plt.xticks(rotation=0, fontsize=15)

plt.legend()
plt.show()

# %%
df_not_churn = df_p2[df_p2['churn_flag']==0] 
print(df_not_churn['customer_code'].count())
# Out:
# 1942145

# %%
df_churn['customer_code'].nunique()
# Out:
# 984

# %%
df_not_churn['customer_code'].nunique()
# Out:
# 3496

# %%
df_p2['customer_code'].nunique()
# Out:
# 4480

# %%
# Create a new 'return' column in df_churn
df_not_churn['return'] = df_not_churn.apply(lambda row: row['value_sales'] if row['order_type_code'] in return_codes else 0, axis=1)

# Aggregate data to calculate total value_sales, total_return, and %return_to_sales
aggregated_df_not_churn = df_not_churn.groupby(['customer_code', 'calendar_year']).agg(
    value_sales=('value_sales', 'sum'),         # Total sales per customer per year
    total_return=('return', lambda x: abs(x.sum()))  # Sum of returns per customer per year, taking absolute value
).reset_index()

# Calculate %return_to_sales without *-1
aggregated_df_not_churn['%return_to_sales'] = (aggregated_df_not_churn['total_return'] / (aggregated_df_not_churn['value_sales']+aggregated_df_not_churn['total_return']))

# Select only the required columns for the output
not_churn_return_df = aggregated_df_not_churn[['customer_code', 'calendar_year', 'value_sales','total_return', '%return_to_sales']]

# Display the result
print(not_churn_return_df)
# Out:
#      customer_code  calendar_year   value_sales  total_return  \
# 0        100050100           2013  4.800610e+06  22540.900000
# 1        100210100           2012  6.637408e+04      0.000000
# 2        100210100           2013  7.041620e+03      0.000000
# 3        100250200           2012  6.564000e+02   1102.200000
# 4        100250200           2013  1.151485e+04      0.000000
# ...            ...            ...           ...           ...
# 6521     ZI8009401           2013  4.436424e+03      0.000000
# 6522     ZI9000101           2012  1.829266e+05   1580.521550
# 6523     ZI9000101           2013  2.802483e+05    598.444776
# 6524     ZI9000102           2012  7.024114e+05   5167.552021
# 6525     ZI9000102           2013  1.024904e+06  41380.337886
#
#       %return_to_sales
# 0             0.004673
# 1             0.000000
# 2             0.000000
# 3             0.626749
# 4             0.000000
# ...                ...
# 6521          0.000000
# 6522          0.008566
# 6523          0.002131
# 6524          0.007303
# 6525          0.038808
#
# [6526 rows x 5 columns]

# %%
# drop negative value sales because they are inactive for over 2 years and not our focus
# select only customer that have return

not_churn_return_df = not_churn_return_df[not_churn_return_df['value_sales'] >0  & (not_churn_return_df['total_return'] >0)]

# %%
# Plot histogram

sns.histplot(data = not_churn_return_df, x= '%return_to_sales')
plt.xlabel("% Product Return Amount / Sales", fontsize=15)
plt.ylabel("number of customer", fontsize=15)
plt.title("Non Churn Customer Distribution of %Product Return Amount/Sales", fontsize=15)
plt.xticks(rotation=0, fontsize=15)

plt.legend()
plt.show()

# %%
churn_return = churn_return_df['%return_to_sales']
not_churn_return = not_churn_return_df['%return_to_sales']

# %%
print(f'Churn Customer Mean %product return/sales' , churn_return_df['%return_to_sales'].mean())
print(f'Non Churn Customer Mean %product return/sales' , not_churn_return_df['%return_to_sales'].mean())
# Out:
# Churn Customer Mean %product return/sales 0.13252986245829818
# Non Churn Customer Mean %product return/sales 0.02458471311907598

# %%
from scipy.stats import shapiro

# Assuming `data_column` is the column you want to test for normality
statistic, p_value = shapiro(churn_return)

# Display the results
print("Shapiro-Wilk Test Statistic:", statistic)
print("P-value:", p_value)

# Interpret the result
if p_value > 0.05:
    print("The data appears to be normally distributed (fail to reject H0).")
else:
    print("The data does not appear to be normally distributed (reject H0).")
# Out:
# Shapiro-Wilk Test Statistic: 0.7402158378113164
# P-value: 1.773305933948647e-17
# The data does not appear to be normally distributed (reject H0).

# %%
from scipy.stats import shapiro

statistic, p_value = shapiro(not_churn_return)

# Display the results
print("Shapiro-Wilk Test Statistic:", statistic)
print("P-value:", p_value)

# Interpret the result
if p_value > 0.05:
    print("The data appears to be normally distributed (fail to reject H0).")
else:
    print("The data does not appear to be normally distributed (reject H0).")
# Out:
# Shapiro-Wilk Test Statistic: 0.4074812943867463
# P-value: 1.8842302829781806e-90
# The data does not appear to be normally distributed (reject H0).

# %%
# Perform Levene's test
stat, p_value = stats.levene(churn_return, not_churn_return)

# Display the result
if p_value < 0.05:
    print("Reject the null hypothesis: Variances are not equal (use Welch's t-test).")
else:
    print("Fail to reject the null hypothesis: Variances are equal (use Student's t-test).")

# Print the statistic and p-value
print(f"Levene's test statistic: {stat}, p-value: {p_value}")
# Out:
# Reject the null hypothesis: Variances are not equal (use Welch's t-test).
# Levene's test statistic: 310.42112379106874, p-value: 5.942832373471681e-68

# %%
# Perform a two-sample t-test # 2 Independent Samples
t_statistic, p_value = stats.ttest_ind(churn_return, not_churn_return ,equal_var=False)

print("t-statistic:", t_statistic)
print("p-value:", p_value)

if p_value < 0.05:
    print("Significantly different")
else:
    print("NOT Significantly different")
# Out:
# t-statistic: 9.075595419248298
# p-value: 1.0358585824886103e-16
# Significantly different

# %% [markdown]
# ## Time Gap between churn and Non-churn #

# %%
Churn_timegap = df_churn[['time_gap', 'order_type_code', 'customer_district_code', 'business_area_code','flag_project_order','abc_class_code']]
Not_Churn_timegap = df_not_churn[['time_gap', 'order_type_code', 'customer_district_code', 'business_area_code','flag_project_order','abc_class_code']]

# %%
# check time gap by product 
Not_Churn_timegap.groupby('flag_project_order')['time_gap'].describe()
# Out:
#                       count                        mean  \
# flag_project_order
# 0                   1773882   2 days 19:37:58.586287024
# 1                     60291  33 days 19:06:20.653828929
#
#                                            std              min  \
# flag_project_order
# 0                   12 days 23:41:58.382489428  0 days 00:00:00
# 1                   49 days 05:09:17.749926460  0 days 00:00:00
#
#                                 25%               50%               75%  \
# flag_project_order
# 0                   0 days 00:00:00   0 days 00:00:00   1 days 00:00:00
# 1                   3 days 00:00:00  21 days 00:00:00  41 days 00:00:00
#
#                                    max
# flag_project_order
# 0                    934 days 00:00:00
# 1                   1672 days 00:00:00

# %%
Churn_timegap_time = Churn_timegap['time_gap'].dt.total_seconds()/ 86400
Not_Churn_timegap_time = Not_Churn_timegap['time_gap'].dt.total_seconds()/ 86400

# %%
sns.histplot(Churn_timegap_time, bins=20)
plt.xlabel('Time Gap (days)')
plt.ylabel('Transaction Frequency')
plt.title('churn customer Time Gap (days)')
plt.show()

# %%
sns.histplot(Not_Churn_timegap_time, bins=20)
plt.xlabel('Time Gap (days)')
plt.ylabel('Transaction Frequency')
plt.title('Not churn customer Time Gap (days)')
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x / 1e6:.1f}M'))
plt.show()

# %%
Not_Churn_timegap_time.max()
# Out:
# 1672.0

# %%
print(f'Churn customer timegap ', Churn_timegap_time.mean())
print(f'Non Churn customer timegap ',Not_Churn_timegap_time.mean())
# Out:
# Churn customer timegap  5.9567658618753505
# Non Churn customer timegap  3.8363164216243506

# %%
from scipy.stats import shapiro

statistic, p_value = shapiro(Churn_timegap_time)

# Display the results
print("Shapiro-Wilk Test Statistic:", statistic)
print("P-value:", p_value)

# Interpret the result
if p_value > 0.05:
    print("The data appears to be normally distributed (fail to reject H0).")
else:
    print("The data does not appear to be normally distributed (reject H0).")
# Out:
# Shapiro-Wilk Test Statistic: 0.3097335276653045
# P-value: 1.8660262234516455e-140
# The data does not appear to be normally distributed (reject H0).

# %%
from scipy.stats import shapiro

statistic, p_value = shapiro(Not_Churn_timegap_time)

# Display the results
print("Shapiro-Wilk Test Statistic:", statistic)
print("P-value:", p_value)

# Interpret the result
if p_value > 0.05:
    print("The data appears to be normally distributed (fail to reject H0).")
else:
    print("The data does not appear to be normally distributed (reject H0).")
# Out:
# Shapiro-Wilk Test Statistic: 0.22477585897561148
# P-value: 4.714673247127282e-236
# The data does not appear to be normally distributed (reject H0).

# %%
# Perform Levene's test
stat, p_value = stats.levene(Churn_timegap_time, Not_Churn_timegap_time)

# Display the result
if p_value < 0.05:
    print("Reject the null hypothesis: Variances are not equal .")
else:
    print("Fail to reject the null hypothesis: Variances are equal .")

# Print the statistic and p-value
print(f"Levene's test statistic: {stat}, p-value: {p_value}")
# Out:
# Reject the null hypothesis: Variances are not equal .
# Levene's test statistic: 514.5725844591425, p-value: 6.649771829738276e-114

# %%
# Perform the two-sample t-test
# Perform a two-sample t-test # 2 Independent Samples
t_statistic, p_value = stats.ttest_ind(Churn_timegap_time, Not_Churn_timegap_time ,equal_var=False)

print("t-statistic:", t_statistic)
print("p-value:", p_value)

if p_value < 0.05:
    print("Significantly different")
else:
    print("NOT Significantly different")
# Out:
# t-statistic: 19.29224215812362
# p-value: 1.6906621601753816e-82
# Significantly different

# %% [markdown]
# ## Outlier Time Gap

# %%
## exclude outlier ##
outlier_timegap_threshold = 365
Churn_timegap_time_clean = Churn_timegap_time[Churn_timegap_time <= outlier_timegap_threshold]
Not_Churn_timegap_time_clean = Not_Churn_timegap_time[Not_Churn_timegap_time <= outlier_timegap_threshold]

# %%
print(f'Churn customer timegap ', Churn_timegap_time_clean .mean())
print(f'Non Churn customer timegap ',Not_Churn_timegap_time_clean.mean())
# Out:
# Churn customer timegap  5.862323766736618
# Non Churn customer timegap  3.7619104745213536

# %%
# Perform the two-sample t-test
# Perform a two-sample t-test # 2 Independent Samples
t_statistic, p_value = stats.ttest_ind(Churn_timegap_time_clean , Not_Churn_timegap_time_clean ,equal_var=False)

print("t-statistic:", t_statistic)
print("p-value:", p_value)

if p_value < 0.05:
    print("Significantly different")
else:
    print("NOT Significantly different")
# Out:
# t-statistic: 20.47042467863766
# p-value: 1.3954046914109668e-92
# Significantly different

# %%
df_p2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1979083 entries, 0 to 1979082
# Data columns (total 47 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   accounting_date           datetime64[ns]
#  1   fiscal_year               int64
#  2   fiscal_month              int64
#  3   calendar_year             int64
#  4   calendar_month            int64
#  5   company_code              int64
#  6   customer_code             object
#  7   customer_district_code    int64
#  8   item_code                 object
#  9   business_area_code        object
#  10  item_group_code           object
#  11  item_class_code           object
#  12  item_type                 object
#  13  bonus_group_code          object
#  14  environment_group_code    object
#  15  technology_group_code     object
#  16  commission_group_code     object
#  17  reporting_classification  object
#  18  light_source              object
#  19  warehouse_code            object
#  20  abc_class_code            object
#  21  abc_class_volume          object
#  22  business_chain_l1_code    object
#  23  business_chain_l1_name    object
#  24  contact_method_code       object
#  25  salesperson_code          object
#  26  order_type_code           object
#  27  market_segment            object
#  28  value_sales               float64
#  29  value_cost                float64
#  30  value_quantity            float64
#  31  value_price_adjustment    int64
#  32  currency                  object
#  33  invoice_number            int64
#  34  line_number               int64
#  35  invoice_date              datetime64[ns]
#  36  customer_order_number     object
#  37  order_date                datetime64[ns]
#  38  unit_price                float64
#  39  profit_margin             float64
#  40  flag_project_order        int64
#  41  export_order_flag         int64
#  42  fx_order_flag             int64
#  43  bus_area_group            object
#  44  profit                    float64
#  45  time_gap                  timedelta64[ns]
#  46  churn_flag                int32
# dtypes: datetime64[ns](3), float64(6), int32(1), int64(12), object(24), timedelta64[ns](1)
# memory usage: 702.1+ MB

# %% [markdown]
# # Check ABC Class

# %%
sns.catplot(data = df_p2, x = "abc_class_code", y = "value_sales", estimator = "sum", kind= "bar", hue = "calendar_year", col = "flag_project_order")
plt.gca().yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{x / 1_000_000:,.0f}M'))
plt.title('Sales by ABC Class')
#plt.xlabel('')
plt.ylabel('Saels')
# Out:
# Text(584.1384354504243, 0.5, 'Saels')

# %%
sns.catplot(data = df_p2, x = "abc_class_code", y = "value_quantity", estimator = "sum", kind = "bar", hue = "calendar_year")
plt.gca().yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{x / 1_000_000:,.0f}M'))
plt.title('Quantity Sold by ABC Class')
#plt.xlabel('')
plt.ylabel('Quantity')
# Out:
# Text(43.76168933256173, 0.5, 'Quantity')

# %%
sns.catplot(data = df_p2, x = "abc_class_volume", y = "value_quantity", estimator = "sum", kind = "bar")
plt.gca().yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{x / 1_000_000:,.0f}M'))

# %%
sns.catplot(data = df_p2, x = "abc_class_volume", y = "value_sales", estimator = "sum", kind = "bar")

# %%
abc = df_p2.groupby("abc_class_code")['value_sales'].sum()
abc = abc.sort_values(ascending = False)
abc
# Out:
# abc_class_code
# J    5.071642e+08
# A    6.147165e+07
# U    5.709150e+07
# C    5.163315e+07
# B    4.450543e+07
# D    4.347197e+07
# I    2.241311e+07
# G    2.107007e+07
# E    6.554847e+06
# F    4.785410e+06
# Name: value_sales, dtype: float64

# %%
nz_list = [530, 535, 540, 520, 545]
nz = df_p2[df_p2['customer_district_code'].isin(nz_list)]
nz = nz.groupby(['customer_district_code'])['profit'].sum()

nz.sort_values(ascending = False)
# Out:
# customer_district_code
# 540    9.164450e+06
# 530    3.482717e+06
# 520    2.943780e+06
# 535    2.626934e+06
# 545    1.131825e+03
# Name: profit, dtype: float64

# %%
df_p2['business_chain_l1_name'].nunique()
# Out:
# 43

# %%
df_agg_custdistrict = df_p2.groupby(
    [ 'calendar_year', 'customer_district_code', 
  ], as_index=False
).agg({
    'value_sales': 'sum',
    'value_cost': 'sum',
    
})

# Create a column profit margin
df_agg_custdistrict['%profit_margin'] = df_agg_custdistrict['value_sales']/df_agg_custdistrict['value_cost']-1
df_agg_custdistrict['profit'] = df_agg_custdistrict['value_sales']-df_agg_custdistrict['value_cost']
df_agg_custdistrict.head(5)
# Out:
#    calendar_year  customer_district_code  value_sales    value_cost  \
# 0           2012                     200  72955060.95  4.106377e+07
# 1           2012                     210  10568410.95  5.653891e+06
# 2           2012                     300  66088689.19  3.671199e+07
# 3           2012                     310   5143453.60  2.747574e+06
# 4           2012                     400  53825890.57  3.031964e+07
#
#    %profit_margin        profit
# 0        0.776628  3.189129e+07
# 1        0.869228  4.914520e+06
# 2        0.800193  2.937670e+07
# 3        0.871998  2.395880e+06
# 4        0.775281  2.350625e+07

# %%
sorted_df = df_agg_custdistrict.sort_values(by='%profit_margin', ascending=False)
sorted_df
# Out:
#     calendar_year  customer_district_code   value_sales    value_cost  \
# 8            2012                     520  2.857915e+06  1.349429e+06
# 24           2013                     520  2.762492e+06  1.327198e+06
# 3            2012                     310  5.143454e+06  2.747574e+06
# 1            2012                     210  1.056841e+07  5.653891e+06
# 17           2013                     210  8.872696e+06  4.793716e+06
# 5            2012                     410  1.235232e+07  6.673687e+06
# 26           2013                     535  2.589239e+06  1.405105e+06
# 21           2013                     410  1.068369e+07  5.821518e+06
# 7            2012                     510  5.567812e+06  3.041025e+06
# 25           2013                     530  3.620137e+06  2.009827e+06
# 2            2012                     300  6.608869e+07  3.671199e+07
# 19           2013                     310  4.036734e+06  2.248947e+06
# 0            2012                     200  7.295506e+07  4.106377e+07
# 4            2012                     400  5.382589e+07  3.031964e+07
# 13           2012                     600  5.506962e+07  3.133058e+07
# 10           2012                     535  3.381873e+06  1.939073e+06
# 23           2013                     510  6.479854e+06  3.716862e+06
# 9            2012                     530  4.405891e+06  2.533484e+06
# 29           2013                     600  4.747996e+07  2.734932e+07
# 11           2012                     540  1.036468e+07  5.975995e+06
# 16           2013                     200  6.491774e+07  3.751250e+07
# 6            2012                     500  2.609542e+07  1.510882e+07
# 22           2013                     500  2.516549e+07  1.464176e+07
# 18           2013                     300  6.273928e+07  3.716563e+07
# 27           2013                     540  1.184473e+07  7.068963e+06
# 20           2013                     400  5.565558e+07  3.347271e+07
# 14           2012                     710  1.284840e+07  9.003643e+06
# 30           2013                     710  1.662528e+07  1.184020e+07
# 12           2012                     545  3.475550e+03  2.557618e+03
# 15           2012                     720  7.509812e+07  6.836489e+07
# 28           2013                     545  3.483453e+03  3.269560e+03
# 31           2013                     720  8.005794e+07  7.540405e+07
#
#     %profit_margin        profit
# 8         1.117870  1.508486e+06
# 24        1.081447  1.435294e+06
# 3         0.871998  2.395880e+06
# 1         0.869228  4.914520e+06
# 17        0.850902  4.078980e+06
# 5         0.850899  5.678635e+06
# 26        0.842737  1.184134e+06
# 21        0.835207  4.862172e+06
# 7         0.830900  2.526787e+06
# 25        0.801219  1.610311e+06
# 2         0.800193  2.937670e+07
# 19        0.794944  1.787787e+06
# 0         0.776628  3.189129e+07
# 4         0.775281  2.350625e+07
# 13        0.757696  2.373904e+07
# 10        0.744067  1.442800e+06
# 23        0.743367  2.762992e+06
# 9         0.739064  1.872407e+06
# 29        0.736056  2.013063e+07
# 11        0.734385  4.388683e+06
# 16        0.730563  2.740525e+07
# 6         0.727165  1.098660e+07
# 22        0.718748  1.052373e+07
# 18        0.688099  2.557365e+07
# 27        0.675597  4.775767e+06
# 20        0.662715  2.218287e+07
# 14        0.427022  3.844755e+06
# 30        0.404138  4.785075e+06
# 12        0.358901  9.179316e+02
# 15        0.098490  6.733230e+06
# 28        0.065419  2.138929e+02
# 31        0.061719  4.653883e+06

# %%
# Calculate time_gap_days from time_gap column
df_p2['time_gap_days'] = df_p2['time_gap'].dt.days

# Copy dataframe correctly
plot_time_gap = df_p2.copy()

# Filter out refund codes
plot_time_gap = plot_time_gap[~plot_time_gap['order_type_code'].isin(refund_codes)]

# Plot using Seaborn
sns.catplot(
    data=plot_time_gap,
    x="abc_class_volume",
    y="time_gap_days",
    estimator="mean",
    kind="bar",
    col="flag_project_order"
)

# Customize the plot
plt.suptitle("Average Time Gap by ABC Class Volume (only purchase transactions)", y=1.05)  # Adjust for subplots
plt.xlabel("ABC Class Volume")
plt.ylabel("Average Time Gap (days)", fontsize =12)
plt.show()
